# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pymongo sentence_transformers
# Out:
# Collecting pymongo
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.6 MB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 10.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dnspython, pymongo, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed dnspython-2.6.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pymongo-4.8.0 sentence_transformers-3.0.1

# %%
# !pip install transformers -U
# !pip install accelerate -U
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting transformers
#   Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed transformers-4.42.3
# Collecting accelerate
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.31.0

# %%
import pymongo

def get_mongo_client(mongo_uri):
    """Establish connection to the MongoDB."""
    try:
        client = pymongo.MongoClient(mongo_uri)
        print("Connection to MongoDB successful")
        return client
    except pymongo.errors.ConnectionFailure as e:
        print(f"Connection failed: {e}")
        return None


mongo_uri = "mongodb+srv://habiakl:***@***.fhfyoiv.mongodb.net/?retryWrites=true&w=majority&appName=Kerberos"

mongo_client = get_mongo_client(mongo_uri)

# Ingest data into MongoDB
db = mongo_client["semantic_tower"]
collection = db["geo"]
# Out:
# Connection to MongoDB successful

# %%
# Delete any existing records in the collection
collection.delete_many({})
# Out:
# DeleteResult({'n': 660, 'electionId': ObjectId('7fffffff0000000000000008'), 'opTime': {'ts': Timestamp(1719650192, 281), 't': 8}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1719650192, 290), 'signature': {'hash': b'\xa9\xe8\\S\xe3\xc6\xb4\nMH\xb9`\x99N\x7f\x97\xa1\x8c E', 'keyId': 7359578748351414277}}, 'operationTime': Timestamp(1719650192, 281)}, acknowledged=True)

# %%
from sentence_transformers import SentenceTransformer

# https://huggingface.co/thenlper/gte-large
embedding_model = SentenceTransformer("thenlper/gte-large")


def get_embedding(text: str) -> list[float]:
    if not text.strip():
        print("Attempted to get embedding for empty text.")
        return []

    embedding = embedding_model.encode(text)

    return embedding.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
# load geo dataset from dataframe
import pandas as pd

dataset_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/llms4ol/geo/data/geo_semantic_primes.csv")
dataset_df = dataset_df.drop(columns=["embedding"]) # remove string embeddings to re-generate embeddings as vectors
dataset_df.loc[dataset_df['primes'].isnull(),'primes'] = dataset_df['entity']  # fill empty primes with entity class itself: this makes it a local universal prime
dataset_df["embedding"] = dataset_df["primes"].apply(get_embedding)

# %%
# insert dataset into mongodb
documents = dataset_df.to_dict("records")
collection.insert_many(documents)

print("Data ingestion into MongoDB completed")
# Out:
# Data ingestion into MongoDB completed

# %%
def vector_search(user_query, collection):
    """
    Perform a vector search in the MongoDB collection based on the user query.

    Args:
    user_query (str): The user's query string.
    collection (MongoCollection): The MongoDB collection to search.

    Returns:
    list: A list of matching documents.
    """

    # Generate embedding for the user query
    query_embedding = get_embedding(user_query)

    if query_embedding is None:
        return "Invalid query or embedding generation failed."

    # Define the vector search pipeline
    pipeline = [
        {
            "$vectorSearch": {
                "index": "vector_index",
                "queryVector": query_embedding,
                "path": "embedding",
                "numCandidates": 660,  # Number of candidate matches to consider
                "limit": 1,  # Return top 1 matches
            }
        },
        {
            "$project": {
                "_id": 0,  # Exclude the _id field
                "entity": 1,  # Include the entity field
                "primes": 1,  # Include the primes field
                "embedding": 1, # Include the embedding field
                "score": {"$meta": "vectorSearchScore"},  # Include the search score
            }
        },
    ]

    # Execute the search
    results = collection.aggregate(pipeline)
    return list(results)

# %%
def get_search_result(query, collection):

    get_knowledge = vector_search(query, collection)

    search_result = ""
    for result in get_knowledge:
        search_result += f"{result.get('entity', 'N/A')}"

    return search_result

# %%
# get list of wordnet entities that need semantic universals
import json

with open("/content/drive/MyDrive/Colab Notebooks/llms4ol/geo/data/geonames_train.json", "r") as json_data:
    geonames_json = json.loads(json_data.read())
    json_data.close()

# get all wordnet entities
entities_list = [i['type'] for i in geonames_json]
# remove all duplicate entities
entities = list(set(entities_list))
len(entities)
# Out:
# 660

# %%
# Conduct query with retrival of sources
term = "Rhinos Casino"
#query = f'Using the Search Results, give the best entity for the term {term} from the list {entities}'
query = f'give the entity for the term {term}'
source_information = get_search_result(query, collection)
print("*** Source Information:", source_information)
combined_information = (
    f"Query: {query}\nSelect the answer from this list {entities} relying on the Search Results:\n{source_information}|"
)

print(combined_information)
# Out:
# *** Source Information: casino
# Query: give the entity for the term Rhinos Casino
# Select the answer from this list ['copper works', 'lake', 'gorge(s)', 'former sugar mill', 'maritime school', 'halting place', 'street', 'desert', 'dry stream bed', 'inlet', 'market', 'meadow', 'military school', 'hospital', 'brewery', 'plain(s)', 'wetland', 'fissure', 'moraine', 'saddle', 'communication center', 'pyramid', 'steps', 'foundry', 'slide', 'post office', 'dike', 'intermittent oxbow lake', 'inspection station', 'windmill', 'lost river', 'storehouse', 'fossilized forest', 'portage', 'oil pipeline terminal', 'ruined dam', 'weir(s)', 'clearing', 'rock desert', 'valley', 'church', 'military installation', 'terminal', 'waterhole(s)', 'railroad signal', 'sewage treatment plant', 'terrace', 'racetrack', 'oilfield', 'nunataks', 'amusement park', 'badlands', 'mesa(s)', 'railroad tunnel', 'ghat', 'baling station', 'estuary', 'spring(s)', 'wadies', 'stream', 'third-order administrative division', 'ruined bridge', 'golf course', 'crater(s)', 'bar', 'cleft(s)', 'historical administrative division ', 'meander neck', 'customs house', 'historical third-order administrative division', 'administrative facility', 'populated place', 'salt evaporation ponds', 'fan', 'abandoned mission', 'section of valley', 'continent', 'heliport', 'island', 'lock(s)', 'synagogue', 'tower', 'salt marsh', 'ponds', 'cuesta(s)', 'railroad', 'estate(s)', 'intermittent pond', 'zone', 'abandoned police post', 'mill(s)', 'abandoned mine', 'oil pipeline', 'canyons', 'gravel area', 'dependent political entity', 'islet', 'lava area', 'spur(s)', 'beacon', 'abandoned prison', 'museum', 'religious site', 'oxbow lake', 'seachannel', 'business center', 'mall', 'experiment station', 'first-order administrative division', 'State Exam Prep Centre', 'arch', 'historical first-order administrative division', 'rise', 'sugar plantation', 'quicksand', 'slope(s)', 'transit terminal', 'islands', 'icecap depression', 'intermittent salt pond(s)', 'bus station', 'agricultural reserve', 'triangulation station', 'intermittent salt lake', 'marine channel', 'artificial island', 'abandoned farm', 'blowhole(s)', 'zoo', 'cultivated area', 'restaurant', 'point', 'leprosarium', 'hills', 'interdune trough(s)', 'meteorological station', 'spur', 'railroad station', 'tram', 'pinnacle', 'boatyard', 'knolls', 'section of island', 'mining area', 'spa', 'gully', 'blowout(s)', 'headwaters', 'landing', 'cemetery', 'caravan route', 'resort', 'technical school', 'tundra', 'drainage basin', 'valleys', 'sand area', 'irrigated field(s)', 'moat', 'glacier(s)', 'sinkhole', 'bridge', 'fuel depot', 'maneuver area', 'lagoons', 'beaches', 'landfill', 'sub-surface dam', 'reserve', 'medical center', 'ravine(s)', 'dispensary', 'abandoned factory', 'coconut grove', 'grove', 'farmstead', 'seat of a third-order administrative division', 'arrugado', 'moor(s)', 'toll gate/barrier', 'shoal', 'power station', 'irrigation canal', 'historical site', 'ditch', 'ridges', 'underground lake', 'seat of a second-order administrative division', 'intermittent pool', 'religious center', 'port', 'water tank', 'cliff(s)', 'convent', 'bus stop', 'tree(s)', 'section of wadi', 'united states government establishment', 'lagoon', 'airport', 'gold mine(s)', 'promontory(-ies)', 'section of intermittent stream', 'tidal flat(s)', 'former inlet', 'reef', 'jetty', 'cone(s)', 'basin', 'coast', 'section of peninsula', 'deep', 'gate', 'seat of a fifth-order administrative division', 'channel', 'scrubland', 'building(s)', 'piece of art', 'shore', 'tunnel', 'logging camp', 'seat of a fourth-order administrative division', 'monument', 'locality', 'stock route', 'rock', 'historical populated place', 'guest house', 'geyser', 'oil well', 'ridge', 'hot spring(s)', 'salt lakes', 'area', 'shoal(s)', 'library', 'hut', 'cairn', 'tea plantation', 'ranch(es)', 'wreck', 'automatic teller machine', 'cutoff', 'flat', 'seat of a first-order administrative division', 'beach', 'shoals', 'talus slope', 'mission', 'overfalls', 'office building', 'dockyard', 'volcano', ...
# casino|

# %%
# authenticate to HF to be able to use some restricted LLMs
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, T5TokenizerFast, T5ForConditionalGeneration
"""
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# CPU Enabled uncomment below 👇🏽
# model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
"""

model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/llms4ol/geo/model/flan-t5-small_geonames_model")
tokenizer = T5TokenizerFast.from_pretrained("/content/drive/MyDrive/Colab Notebooks/llms4ol/geo/model/flan-t5-small_geonames_tokenizer")
model.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=32128, bias=False)
# )

# %%
import torch

Q_LEN = 512   # Question Length
DEVICE = "cuda:0"

# test example
term = "Banana Bank"
query = f"""{term}"""
source_information = get_search_result(query, collection)
print("*** SOURCE:", source_information)
combined_information = (
    f"""{source_information}"""
    #f"""[CLS] {source_information} [SEP] {term}"""
    #f""""""
)
"""
# Moving tensors to GPU
input_ids = tokenizer(combined_information, return_tensors="pt").to("cuda")
response = model.generate(**input_ids, max_new_tokens=500)
response_string = tokenizer.decode(response[0])
#print(tokenizer.decode(response[0]))
"""
inputs = tokenizer(term, combined_information, max_length=Q_LEN, padding="max_length", truncation=True, add_special_tokens=True)

input_ids = torch.tensor(inputs["input_ids"], dtype=torch.long).to(DEVICE).unsqueeze(0)
attention_mask = torch.tensor(inputs["attention_mask"], dtype=torch.long).to(DEVICE).unsqueeze(0)

outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask)

predicted_type = tokenizer.decode(outputs.flatten(), skip_special_tokens=True)

"""
# initializing substrings
sub1 = "<pad> "
sub2 = "</s>"

# getting elements in between using split() and join()
answer = ''.join(response_string.split(sub1)[1].split(sub2)[0])
"""
# printing result
#print("The answer is :",answer)
print("The answer is :",predicted_type)
print(type(predicted_type))
# Out:
# *** SOURCE: section of bank
# The answer is : bank
# <class 'str'>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1249: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
import numpy as np
import torch

Q_LEN = 512   # Question Length
DEVICE = "cuda:0"

def precision_at_k(actual, predicted):
    act_set = set(actual)
    pred_set = set(predicted)
    result = len(act_set & pred_set) / float(len(predicted))
    return result*100

def apk(actual, predicted, k):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if not actual:
        return 0.0
    if len(predicted)>k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i,p in enumerate(predicted):
        # first condition checks whether it is valid prediction
        # second condition checks if prediction is not repeated
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)
    return score / min(len(actual), k)


def mapk(actual, predicted, k):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int,
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a, p, k) for a,p in zip(actual, predicted)])


class EvaluationMetrics:

    def __init__(self, ks:list, metric="map") -> None:
        self.ks = ks
        self.metric=metric

    def evaluate(self, actual:list, predicted:list):
        if self.metric == "map":
            return self.MAP(actual, predicted)
        else:
            return self.AP(actual, predicted)

    def MAP(self, actual:list, predicted:list):
        results_dict = {}
        for k in self.ks:
            results_dict["MAP@"+str(k)] = mapk(actual=actual, predicted=predicted, k=k)
        return results_dict

    def AP(self, actual:list, predicted:list):
        results_dict = {}
        for k in self.ks:
            results_dict["AP@"+str(k)] = [apk(actual=actual, predicted=predicted, k=k)
                                          for a, p in zip(actual, predicted)]
        return results_dict

def predict_answer(term, combined_information, ref_type=None):

    inputs = tokenizer(term, combined_information, max_length=Q_LEN, padding="max_length", truncation=True, add_special_tokens=True)
    input_ids = torch.tensor(inputs["input_ids"], dtype=torch.long).to(DEVICE).unsqueeze(0)
    attention_mask = torch.tensor(inputs["attention_mask"], dtype=torch.long).to(DEVICE).unsqueeze(0)
    outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    predicted_type = tokenizer.decode(outputs.flatten(), skip_special_tokens=True)

    if ref_type:
        # Load the MAP@K metric for K=1
        score = mapk([ref_type], [predicted_type], 1)

        print("Term: \n", term)
        return {
            "Reference Type: ": ref_type,
            "Predicted Type: ": predicted_type,
            "MAP@1: ": score
        }
    else:
        return {
            "Predicted Type: ": predicted_type
            }

# %%
# prepare final submission
submission = []

# load test set for final submission
with open("/content/drive/MyDrive/Colab Notebooks/llms4ol/geo/data/A.2(FS)_GeoNames_Test.json", "r") as json_data:
    geo_test_json = json.loads(json_data.read())
    json_data.close()

# test predictions
for row in geo_test_json:
  termid = row["ID"]
  term = row["term"]
  print("*** TERM ***")
  print(term)
  query = f"""{term}"""
  source_information = get_search_result(query, collection)
  combined_information = (
      f"""{source_information}"""
  )
  predicted_type = predict_answer(term, combined_information)["Predicted Type: "]
  # construct result
  result_dict = {}
  result_dict["ID"] = termid
  result_dict["type"] = []
  result_dict["type"].append(predicted_type)
  # add result to final submission
  submission.append(result_dict)

# write final submission to JSON file to adhere to submission format
with open("A.1(FS)_Geo_submission.json", "w") as final:
    json.dump(submission, final)

print("************* SUBMISSION FILE GENERATION SUCCESSFUL *************")
# Out:
# *** TERM ***
# Coll de Vista
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1249: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# *** TERM ***
# Estancia La Raquelita
# *** TERM ***
# Fabrica La Ramada
# *** TERM ***
# Rio Lara
# *** TERM ***
# Arroyo La Quesera
# *** TERM ***
# Puesto La Puntilla
# *** TERM ***
# Estancia La Punta
# *** TERM ***
# La Puerta Verde
# *** TERM ***
# La Puente
# *** TERM ***
# La Promesa
# *** TERM ***
# Cordon de La Potrerillos
# *** TERM ***
# Estancia La Positiva
# *** TERM ***
# La Poma
# *** TERM ***
# Cerro de La Polcura
# *** TERM ***
# La Playosa
# *** TERM ***
# Estancia La Plata
# *** TERM ***
# Mogote La Pintada
# *** TERM ***
# La Perseverancia
# *** TERM ***
# La Penas
# *** TERM ***
# La Pega
# *** TERM ***
# Estancia La Pava
# *** TERM ***
# La Pastora
# *** TERM ***
# Cerro La Parva
# *** TERM ***
# La Paquita
# *** TERM ***
# Estancia La Panchita
# *** TERM ***
# Estero La Paloma
# *** TERM ***
# La Palmita
# *** TERM ***
# La Palmera
# *** TERM ***
# La Palma
# *** TERM ***
# Isla La Paciencia
# *** TERM ***
# Arroyo Lapachal
# *** TERM ***
# La Otomana
# *** TERM ***
# La Osamenta
# *** TERM ***
# Arroyo La Ortiguita
# *** TERM ***
# La Ofelia
# *** TERM ***
# Estancia La Nutria
# *** TERM ***
# Almacen La Natita
# *** TERM ***
# Estancia La Natalia
# *** TERM ***
# La Nacion
# *** TERM ***
# La Muneca
# *** TERM ***
# Lamparas
# *** TERM ***
# La Mora Marcada
# *** TERM ***
# Fondeadero La Mision
# *** TERM ***
# Estancia La Milagrosa
# *** TERM ***
# Laguna La Meseta
# *** TERM ***
# Cerro La Meseta
# *** TERM ***
# Puesto La Mesada
# *** TERM ***
# Puesto La Media Luna
# *** TERM ***
# Puesto Lambrano
# *** TERM ***
# Estancia La Maya
# *** TERM ***
# Cremeria La Martona Numero Dos
# *** TERM ***
# Estancia La Martineta
# *** TERM ***
# Estancia La Markonia
# *** TERM ***
# Estancia La Maria Rosa
# *** TERM ***
# La Maria Number 3
# *** TERM ***
# Estancia La Maria Angela
# *** TERM ***
# Laguna La Maria
# *** TERM ***
# Almacen La Maria
# *** TERM ***
# La Manuela
# *** TERM ***
# Estancia La Manola
# *** TERM ***
# Puesto La Manija
# *** TERM ***
# Lomadas de La Maniera
# *** TERM ***
# La Lusitana
# *** TERM ***
# Estancia La Luisa Sur
# *** TERM ***
# Laguna La Loquita
# *** TERM ***
# Estancia La Lomita
# *** TERM ***
# Laguna La Loca
# *** TERM ***
# Colonia La Llave Vieja
# *** TERM ***
# Colonia La Llave Sur
# *** TERM ***
# La Lipela
# *** TERM ***
# Estancia La Leonia
# *** TERM ***
# Rio La Leona
# *** TERM ***
# Cerro L. Aleman
# *** TERM ***
# Estancia La Langosta
# *** TERM ***
# La Junta
# *** TERM ***
# Colonia La Juanita
# *** TERM ***
# La Juana Rosa
# *** TERM ***
# Estancia La Jorgelina
# *** TERM ***
# Cumbre de las Lajas
# *** TERM ***
# Tunel La Invernada Norte
# *** TERM ***
# Estancia La Iberica
# *** TERM ***
# La Higuera del Alumbre
# *** TERM ***
# La Higuera
# *** TERM ***
# Estancia La Haydee Segunda
# *** TERM ***
# Cerro de la Lagunita
# *** TERM ***
# Cerro de la Laguna Verde
# *** TERM ***
# Estacion Laguna Seca
# *** TERM ***
# Estancia Laguna Sarmiento
# *** TERM ***
# Estancia Laguna Larga
# *** TERM ***
# Laguna Grande
# *** TERM ***
# Cerro Laguna Esperanza
# *** TERM ***
# La Guardia
# *** TERM ***
# Estancia La Gringa
# *** TERM ***
# Portezuelo de las Lagrimas
# *** TERM ***
# Escuela La Grande del Sur
# *** TERM ***
# Estancia La Grampa Vieja
# *** TERM ***
# Cerro de los Lagos
# *** TERM ***
# Departamento de Lago Argentino
# *** TERM ***
# Cordon de La Gloria
# *** TERM ***
# Estancia La Genoveva
# *** TERM ***
# Estancia La Gambeta
# *** TERM ***
# La Florida Vieja
# *** TERM ***
# La Flor
# *** TERM ***
# La Estrella
# *** TERM ***
# La Estrechura
# *** TERM ***
# La Estrada
# *** TERM ***
# La Estanciera
# *** TERM ***
# La Esquina
# *** TERM ***
# Puesto La Esmeralda
# *** TERM ***
# Estancia La Ensenada
# *** TERM ***
# La Ensenada
# *** TERM ***
# Laguna La Dulce
# *** TERM ***
# Estacion La Dorita
# *** TERM ***
# Estancia La Dora
# *** TERM ***
# Puerto La Diana
# *** TERM ***
# La Cumbrera
# *** TERM ***
# Puesto La Cueva
# *** TERM ***
# Almacen La Cruz del Sur
# *** TERM ***
# Cerro La Cruzada
# *** TERM ***
# Cremeria La Criolla
# *** TERM ***
# La Costosa
# *** TERM ***
# Arroyo La Cortadera
# *** TERM ***
# La Cienaguita
# *** TERM ***
# La Cienaga de Cumillango
# *** TERM ***
# La Cienaga
# *** TERM ***
# Estancia La Chiquita Oeste
# *** TERM ***
# Puesto La Chingola
# *** TERM ***
# Quebrada La Chilca
# *** TERM ***
# La Chica Agraciada
# *** TERM ***
# Laguna La Chanchera
# *** TERM ***
# La Chacrita de los Padres
# *** TERM ***
# Laguna La Central
# *** TERM ***
# La Celina
# *** TERM ***
# Puesto La Cebruna
# *** TERM ***
# Colonia La Cautiva
# *** TERM ***
# Estancia La Catin
# *** TERM ***
# Estancia La Casualidad
# *** TERM ***
# Estancia La Carrera
# *** TERM ***
# Estancia La Carola
# *** TERM ***
# La Carmencita
# *** TERM ***
# La Carmencita
# *** TERM ***
# La Candelaria
# *** TERM ***
# La Canada
# *** TERM ***
# La Caledonia
# *** TERM ***
# La Calderilla
# *** TERM ***
# La Caldera
# *** TERM ***
# Laguna La Brea
# *** TERM ***
# Vega La Botijuela
# *** TERM ***
# Estancia La Bernabela
# *** TERM ***
# La Beatriz
# *** TERM ***
# Estancia La Baskonia
# *** TERM ***
# Arroyo La Barranquita
# *** TERM ***
# La Barrancosa
# *** TERM ***
# La Barba
# *** TERM ***
# Roca La Bala
# *** TERM ***
# La Azufrera
# *** TERM ***
# La Asturiana
# *** TERM ***
# Estancia La Argentina Norte
# *** TERM ***
# Colonia La Argentina
# *** TERM ***
# Cerro La Arena
# *** TERM ***
# Estancia La Araza
# *** TERM ***
# La Angostura
# *** TERM ***
# Puesto La Angelita
# *** TERM ***
# La Angelita
# *** TERM ***
# Puesto La Angelina
# *** TERM ***
# Estancia La Amelia
# *** TERM ***
# La Amelia
# *** TERM ***
# Laguna La Amarga
# *** TERM ***
# Puesto La Amalia
# *** TERM ***
# La Amalia
# *** TERM ***
# Estancia La Alsacia
# *** TERM ***
# La Alicia
# *** TERM ***
# Estancia La Alfalfa
# *** TERM ***
# Aguada La Alazana
# *** TERM ***
# Arroyo La Aguada
# *** TERM ***
# Puesto La Adela
# *** TERM ***
# La Abundancia
# *** TERM ***
# La Abundancia
# *** TERM ***
# Arroyo Klondike
# *** TERM ***
# Apeadero Kilometro 1448
# *** TERM ***
# Desvio Kilometro 1412
# *** TERM ***
# Apeadero Kilometro 1213
# *** TERM ***
# Kilometro 1137
# *** TERM ***
# Apeadero Kilometro 921
# *** TERM ***
# Kilometro 797
# *** TERM ***
# Apeadero Kilometro 579
# *** TERM ***
# Desvio Kilometro 503
# *** TERM ***
# Apeadero Kilometro 499
# *** TERM ***
# Kilometro 473
# *** TERM ***
# Desvio Kilometro 436
# *** TERM ***
# Embarcadero Kilometro 433
# *** TERM ***
# Kilometro 312
# *** TERM ***
# Desvio Kilometro 168
# *** TERM ***
# Apeadero Kilometro 131
# *** TERM ***
# Kilometro 96.2
# *** TERM ***
# Apeadero Kilometro 41
# *** TERM ***
# Apeadero Kilometro 28
# *** TERM ***
# Apeadero Kilometro 8
# *** TERM ***
# Cerro Kensel
# *** TERM ***
# Junquillar
# *** TERM ***
# Bajo del Juncal
# *** TERM ***
# Jumi Pozo
# *** TERM ***
# Estancia Julia
# *** TERM ***
# Arroyo Juico
# *** TERM ***
# Jueya
# *** TERM ***
# Puesto de Juanes
# *** TERM ***
# Carretera Juan de Garay
# *** TERM ***
# Chacra J. Sesma
# *** TERM ***
# J. Palomo
# *** TERM ***
# Estacion Josefina Sur
# *** TERM ***
# J.F. Vilela
# *** TERM ***
# Estancia J.F. Auger
# *** TERM ***
# Punta Jesse
# *** TERM ***
# Fondeadero Janssen
# *** TERM ***
# Puesto Jalil
# *** TERM ***
# Jaguel de Seijares
# *** TERM ***
# Rio Jague
# *** TERM ***
# Peninsula Jabali
# *** TERM ***
# Isla del Jabali
# *** TERM ***
# Ismiango
# *** TERM ***
# Isleta
# *** TERM ***
# Isla de Cuba
# *** TERM ***
# Departamento de Ischilin
# *** TERM ***
# Ischichusca
# *** TERM ***
# Islas Isabel
# *** TERM ***
# Canal Irigoyen
# *** TERM ***
# Quebrada Invernadita
# *** TERM ***
# Quebrada de la Invernada
# *** TERM ***
# Ingenio San Pablo
# *** TERM ***
# Ingenio Cruz Alta
# *** TERM ***
# Ingenio Amalia
# *** TERM ***
# Ingeniero Thompson
# *** TERM ***
# Estacion Ingeniero Matias G. Sanchez
# *** TERM ***
# Quebrada Ingeniero J.S. Corti
# *** TERM ***
# Ingeniero Foster
# *** TERM ***
# Canada del Infiernito
# *** TERM ***
# Quebrada de Infiernillo
# *** TERM ***
# Puesto de los Indios
# *** TERM ***
# Indio Rico
# *** TERM ***
# Cerro Indio
# *** TERM ***
# Indacochea
# *** TERM ***
# Laguna Incahuasi
# *** TERM ***
# Cerro Impodi
# *** TERM ***
# Monte Iliria
# *** TERM ***
# Laguna II
# *** TERM ***
# Cerro Igneo
# *** TERM ***
# Loma Ignacio
# *** TERM ***
# Laguna Ignacio
# *** TERM ***
# Cerro Iglesias
# *** TERM ***
# Ichipuca
# *** TERM ***
# Rio Icha Cruz
# *** TERM ***
# Paso de Icalma
# *** TERM ***
# Ibarlucea
# *** TERM ***
# Huyamampa
# *** TERM ***
# Estancia Hurlingham
# *** TERM ***
# Humaya
# *** TERM ***
# Arroyo Huiri Huiri
# *** TERM ***
# Cerro Huichaira
# *** TERM ***
# Huerta
# *** TERM ***
# Cajon de la Huecu
# *** TERM ***
# Hueco Blanco
# *** TERM ***
# Huascan
# *** TERM ***
# Sierra de Huantraico
# *** TERM ***
# Huanguelen
# *** TERM ***
# Quebrada Huaitiquina
# *** TERM ***
# Arroyo Huaico Hondo
# *** TERM ***
# Huaico Hondo
# *** TERM ***
# Rio Huaco
# *** TERM ***
# Arroyo Huaca Mamuil
# *** TERM ***
# Huaca Lauquen
# *** TERM ***
# Huacahue
# *** TERM ***
# Cerro del Hoyo
# *** TERM ***
# Pampa de las Horquetas
# *** TERM ***
# Cerro Horquetas
# *** TERM ***
# Rio Hornillos
# *** TERM ***
# Ventisquero Horcones Inferior
# *** TERM ***
# Horconcito
# *** TERM ***
# Puerto Hoppner
# *** TERM ***
# Quebrada Honda
# *** TERM ***
# Fondeadero Homero
# *** TERM ***
# Sierra Hombre Muerto
# *** TERM ***
# Hill Station
# *** TERM ***
# Banado de las Higueritas
# *** TERM ***
# Apeadero Higuerita
# *** TERM ***
# Meson de Hierro
# *** TERM ***
# Rio Hielo
# *** TERM ***
# Estancia Henning
# *** TERM ***
# Puesto Helado
# *** TERM ***
# Estancia Hassan
# *** TERM ***
# Estancia Gurruchaga
# *** TERM ***
# Departamento de Gueer Aike
# *** TERM ***
# Rio Guenguel
# *** TERM ***
# Rio Guayamba
# *** TERM ***
# Sierra de Guasayan
# *** TERM ***
# Cerro Guasamayo
# *** TERM ***
# Cabo Guardian
# *** TERM ***
# Vega de Guanaquero
# *** TERM ***
# Cerro del Guanaco
# *** TERM ***
# Rio Gualjaina
# *** TERM ***
# Guaico Grande
# *** TERM ***
# Cerro Guadaloso
# *** TERM ***
# Lomas Guadalosas
# *** TERM ***
# Laguna Greenschield
# *** TERM ***
# Pena Granito
# *** TERM ***
# Salinas Grandes
# *** TERM ***
# Medanos Grandes
# *** TERM ***
# Isla Grande del Rio Chico
# *** TERM ***
# Laguna Grande
# *** TERM ***
# Gran Bajo Salitroso
# *** TERM ***
# Estacion Granadero Basilio Bustos
# *** TERM ***
# Graciarena
# *** TERM ***
# Graciana
# *** TERM ***
# Cerro Gorro Frigio
# *** TERM ***
# Cerro el Gordillo
# *** TERM ***
# Gondra
# *** TERM ***
# Estero Golondrinas
# *** TERM ***
# Golondrina
# *** TERM ***
# Godoy
# *** TERM ***
# Estancia Gimenez
# *** TERM ***
# Pampa del Gigantillo
# *** TERM ***
# Medano Gigante
# *** TERM ***
# Germania
# *** TERM ***
# Puesto Gente Grande
# *** TERM ***
# Estacion General Villegas
# *** TERM ***
# General Villegas
# *** TERM ***
# Colonia General San Martin
# *** TERM ***
# General San Martin
# *** TERM ***
# General Pizarro
# *** TERM ***
# General Pico
# *** TERM ***
# Departamento de General Ocampo
# *** TERM ***
# Colonia General Necochea
# *** TERM ***
# General Belgrano
# *** TERM ***
# General Baldissera
# *** TERM ***
# Embarcadero General Amigorena
# *** TERM ***
# General Alvear
# *** TERM ***
# Laguna Gegena
# *** TERM ***
# Colonia Garibaldi
# *** TERM ***
# Arroyo Garabato
# *** TERM ***
# Isla Gama
# *** TERM ***
# Galvez
# *** TERM ***
# Puesto del Galpon
# *** TERM ***
# Gallego Muerto
# *** TERM ***
# Bajo de los Galeses
# *** TERM ***
# Gaboto
# *** TERM ***
# Desvio Futa Ruin
# *** TERM ***
# Capilla de Funes
# *** TERM ***
# Bajada del Fuerte
# *** TERM ***
# Fuentes del Coyle
# *** TERM ***
# Frisia
# *** TERM ***
# Rio Frio
# *** TERM ***
# Jaguel Franzua
# *** TERM ***
# Sierra de los Frailes
# *** TERM ***
# Fortin Tiburcio
# *** TERM ***
# Estancia Fortin Las Tunas
# *** TERM ***
# Cerro Fortin
# *** TERM ***
# Fontezuela
# *** TERM ***
# Cerro Fonck
# *** TERM ***
# F. Munoz
# *** TERM ***
# Salina de Flores
# *** TERM ***
# Flor de Loto
# *** TERM ***
# Estancia Floradora
# *** TERM ***
# Laguna de las Flamencas
# *** TERM ***
# Laguna del Flaco
# *** TERM ***
# Fitarruin
# *** TERM ***
# Cajon de los Filos
# *** TERM ***
# Fila Miche
# *** TERM ***
# Quebrada del Fierro
# *** TERM ***
# Valle de Fiambala
# *** TERM ***
# Ferri
# *** TERM ***
# Ferreyra
# *** TERM ***
# Canadon Ferraris
# *** TERM ***
# Paso de la Felicidad
# *** TERM ***
# Bahia Falsa
# *** TERM ***
# Cerros Excursion
# *** TERM ***
# Estrella
# *** TERM ***
# Laguna Esteritos
# *** TERM ***
# Esteban Rams
# *** TERM ***
# Punta Este
# *** TERM ***
# Estancia Santa Ines
# *** TERM ***
# Estancia San Miguel North
# *** TERM ***
# Puesto de Estancia Rospentek
# *** TERM ***
# Puesto de Estancia Plater
# *** TERM ***
# Estancia Las Playas
# *** TERM ***
# Estancia Las Palmas
# *** TERM ***
# Estancia Las Lomas
# *** TERM ***
# Estancia Las Cortaderas
# *** TERM ***
# Estancia La Sarah
# *** TERM ***
# Puesto de Estancia La Nueva Oriental
# *** TERM ***
# Estancia La Leontine
# *** TERM ***
# Estancia Isla Verde
# *** TERM ***
# Puesto de Estancia Gueer Aike
# *** TERM ***
# Punta Estancia
# *** TERM ***
# Cerro de la Estancia
# *** TERM ***
# Laguna del Estado
# *** TERM ***
# Esquiu
# *** TERM ***
# Esquinita
# *** TERM ***
# Estancia Esquina Monte
# *** TERM ***
# Cerro Esquina
# *** TERM ***
# Canadon Esquichiu
# *** TERM ***
# Estancia Esquel
# *** TERM ***
# Espiadero
# *** TERM ***
# Puesto de la Esperanza
# *** TERM ***
# Portezuelo Esperanza
# *** TERM ***
# Cerro la Esperanza
# *** TERM ***
# Cienaga de los Espejos
# *** TERM ***
# Estacion Espejo
# *** TERM ***
# Canadon de los Espanoles
# *** TERM ***
# Estancia Esmeradita
# *** TERM ***
# Cerro Escuela Ochenta y Cuatro
# *** TERM ***
# Laguna Escondida
# *** TERM ***
# Arroyo de la Escondida
# *** TERM ***
# Arroyo de las Escobas
# *** TERM ***
# Escaya
# *** TERM ***
# Cerro Escalona
# *** TERM ***
# Villa Ermila
# *** TERM ***
# Canada de la Entrada
# *** TERM ***
# Laguna de la Ensenada
# *** TERM ***
# Arroyo de la Ensenada
# *** TERM ***
# Emilio V. Bunge
# *** TERM ***
# Emilia
# *** TERM ***
# Rio Zurdo
# *** TERM ***
# Puesto El Zorro
# *** TERM ***
# Estancia El Zorro
# *** TERM ***
# El Zorro
# *** TERM ***
# El Zapallar
# *** TERM ***
# Apeadero El Zaino
# *** TERM ***
# El Volcan
# *** TERM ***
# El Vergel
# *** TERM ***
# Colonia El Usillal
# *** TERM ***
# Estancia El Unro
# *** TERM ***
# El Turbio
# *** TERM ***
# Puesto El Tuma
# *** TERM ***
# El Triunfo
# *** TERM ***
# Aguada El Tramposo
# *** TERM ***
# Estancia El Tongoriro
# *** TERM ***
# El Tipal
# *** TERM ***
# Mina El Tio
# *** TERM ***
# El Tenor
# *** TERM ***
# El Tarro
# *** TERM ***
# El Talamar
# *** TERM ***
# Sierra El Tala
# *** TERM ***
# El Sombrero
# *** TERM ***
# El Socorro
# *** TERM ***
# Pampa El Silencio
# *** TERM ***
# El Silencio
# *** TERM ***
# Estancia El Siete
# *** TERM ***
# El Shincal
# *** TERM ***
# Puesto El Sauzal
# *** TERM ***
# Estancia El Saucecito
# *** TERM ***
# Apeadero El Salto
# *** TERM ***
# Laguna El Salitral
# *** TERM ***
# El Salitral
# *** TERM ***
# Canada El Rosillo
# *** TERM ***
# El Rincon
# *** TERM ***
# El Remate
# *** TERM ***
# El Recreo
# *** TERM ***
# Estancia El Raulito
# *** TERM ***
# Puesto El Rastrojo
# *** TERM ***
# El Rafango
# *** TERM ***
# Estancia El Quique
# *** TERM ***
# El Quipon
# *** TERM ***
# Puesto El Puntudo
# *** TERM ***
# Estancia El Puntudo
# *** TERM ***
# El Puesto
# *** TERM ***
# El Puca
# *** TERM ***
# Establecimiento El Prado
# *** TERM ***
# El Pozo Santiago
# *** TERM ***
# Estancia El Poyo
# *** TERM ***
# Puesto El Potrerito
# *** TERM ***
# Colonia El Porvenir
# *** TERM ***
# Estancia El Poncho Verde
# *** TERM ***
# El Poleo
# *** TERM ***
# Canadon El Pluma
# *** TERM ***
# El Plateado
# *** TERM ***
# Almacen El Piemonte
# *** TERM ***
# Puesto El Peregrino
# *** TERM ***
# Puesto El Peral
# *** TERM ***
# Estancia El Paysandu
# *** TERM ***
# Apeadero El Payador
# *** TERM ***
# Estancia El Pastizal
# *** TERM ***
# El Pastal
# *** TERM ***
# El Paraiso
# *** TERM ***
# Arroyo El Pantanoso
# *** TERM ***
# El Pantanoso
# *** TERM ***
# El Pampero
# *** TERM ***
# El Palomar
# *** TERM ***
# Lagunas El Palo
# *** TERM ***
# Puesto El Pajarito
# *** TERM ***
# Estancia El Paisano
# *** TERM ***
# Cabana El Ombu
# *** TERM ***
# Puesto El Olivo
# *** TERM ***
# Estancia El Nuevo
# *** TERM ***
# Estancia El Nire
# *** TERM ***
# Cerro El Nino Muerto
# *** TERM ***
# Arroyo El Negro
# *** TERM ***
# El Negro
# *** TERM ***
# Estancia El Morrito
# *** TERM ***
# Colonia El Moro
# *** TERM ***
# Arroyo El Mono
# *** TERM ***
# Puesto El Molino Chico
# *** TERM ***
# El Mistol
# *** TERM ***
# El Milagro
# *** TERM ***
# El Medano
# *** TERM ***
# Cerro El Matuasto
# *** TERM ***
# El Manzano
# *** TERM ***
# El Lucero
# *** TERM ***
# El Lipetren
# *** TERM ***
# Estancia El Linyera
# *** TERM ***
# El Lechuzo
# *** TERM ***
# Puesto El Lecheron
# *** TERM ***
# Almacen El Laurel
# *** TERM ***
# Estancia El Jumial
# *** TERM ***
# Volcan El Jinete
# *** TERM ***
# El Jardin
# *** TERM ***
# El Huecu
# *** TERM ***
# El Hoyo
# *** TERM ***
# El Hormiguero
# *** TERM ***
# Puesto El Horcon
# *** TERM ***
# Almacen El Hinojo
# *** TERM ***
# El Halladito
# *** TERM ***
# El Guayacan
# *** TERM ***
# Estancia El Guanaco
# *** TERM ***
# El Gitanillo
# *** TERM ***
# El Gigante
# *** TERM ***
# Estancia El Gaucho Nuevo
# *** TERM ***
# El Florentino
# *** TERM ***
# Cerro El Falso
# *** TERM ***
# Estancia El Fabre
# *** TERM ***
# El Ensayo
# *** TERM ***
# El Encon
# *** TERM ***
# El Dorado
# *** TERM ***
# Playa El Doradillo
# *** TERM ***
# Puesto El Doce
# *** TERM ***
# El Dobladero de la Viuda
# *** TERM ***
# Puesto El Diecisiete
# *** TERM ***
# Almacen El Dia
# *** TERM ***
# Cabana El Destino
# *** TERM ***
# El Destierro
# *** TERM ***
# El Desmonte
# *** TERM ***
# El Corito
# *** TERM ***
# Estancia El Congreso
# *** TERM ***
# El Clavillo
# *** TERM ***
# Estancia El Chato
# *** TERM ***
# El Chaquito
# *** TERM ***
# Estancia El Chalet
# *** TERM ***
# El Centinela
# *** TERM ***
# Puesto El Catorce
# *** TERM ***
# El Carril
# *** TERM ***
# El Carreton
# *** TERM ***
# El Carmen
# *** TERM ***
# Almacen El Calden
# *** TERM ***
# El Cajon
# *** TERM ***
# El Cacuy
# *** TERM ***
# Puesto El Buen Pastor
# *** TERM ***
# El Buen Lugar
# *** TERM ***
# El Bolson
# *** TERM ***
# Arroyo El Bellaco
# *** TERM ***
# Apeadero El Bayo
# *** TERM ***
# El Barrial
# *** TERM ***
# El Banado
# *** TERM ***
# Colonia El Balde
# *** TERM ***
# El Balde
# *** TERM ***
# Estancia El Arco Iris
# *** TERM ***
# Cerro El Alumbre
# *** TERM ***
# El Algarrobo
# *** TERM ***
# Canal El Alba
# *** TERM ***
# Estancia El Alazan
# *** TERM ***
# Puesto El Alamo
# *** TERM ***
# El Aibe
# *** TERM ***
# Laguna Dulcinea
# *** TERM ***
# Puerto Dudoso
# *** TERM ***
# Drysdale
# *** TERM ***
# Dragones
# *** TERM ***
# Arroyo Dos Lagunas
# *** TERM ***
# Cerro Dos Cabezas de Carnero
# *** TERM ***
# Empalme Dorrego
# *** TERM ***
# Estancia Doraike
# *** TERM ***
# Rio Doncellas
# *** TERM ***
# Estancia Don Bosco Chico
# *** TERM ***
# Dona Julia
# *** TERM ***
# Donado
# *** TERM ***
# Colonia Domingo Matheu
# *** TERM ***
# Doctor Rogelio Cortizo
# *** TERM ***
# Destacamento Policia Diego Ritchie
# *** TERM ***
# Diego Ritchie
# *** TERM ***
# Colonia Dieciseis de Octubre
# *** TERM ***
# Laguna Diaz
# *** TERM ***
# Diamante
# *** TERM ***
# Quebrada del Diablo
# *** TERM ***
# Portezuelo de los Despoblados
# *** TERM ***
# Desmochado Afuera
# *** TERM ***
# Cerro Desfiladero
# *** TERM ***
# Laguna Desempeno
# *** TERM ***
# Lago Deseado
# *** TERM ***
# Desaguadero
# *** TERM ***
# Colonia Delia
# *** TERM ***
# Punta Delgada
# *** TERM ***
# Darwin
# *** TERM ***
# Arroyo Dario Delgado
# *** TERM ***
# Daniel Donovan
# *** TERM ***
# Pozo del Cuzco
# *** TERM ***
# Sierra de Cutancunue
# *** TERM ***
# Curtiembre
# *** TERM ***
# Arroyo Curi Leuvu
# *** TERM ***
# Estancia Cura Malal Chico
# *** TERM ***
# Canadon Cura-Laufquen
# *** TERM ***
# Curaco
# *** TERM ***
# Laguna del Cura
# *** TERM ***
# Estacion Cullen
# *** TERM ***
# Cullen
# *** TERM ***
# Sierra Culampaja
# *** TERM ***
# Cueva Blanca
# *** TERM ***
# Rio de la Cueva
# *** TERM ***
# Morro de la Cuesta
# *** TERM ***
# Cerro Cuchillo Cura
# *** TERM ***
# Cuchihuman
# *** TERM ***
# Cuatro Vientos
# *** TERM ***
# Cerro Cuatro Puntas
# *** TERM ***
# Pampa del Cuarenta y Seis
# *** TERM ***
# Alto de la Cruz
# *** TERM ***
# Portezuelo Crespo Poniente
# *** TERM ***
# Estancia Cracker
# *** TERM ***
# Lomas del Coyte
# *** TERM ***
# Coyaguaima
# *** TERM ***
# Costosa
# *** TERM ***
# Cerros Cortados
# *** TERM ***
# Portillo Cortadera
# *** TERM ***
# Mogote Cortadera
# *** TERM ***
# Cuesta Cortadera
# *** TERM ***
# Cerro Cortadera
# *** TERM ***
# Abra Cortadera
# *** TERM ***
# Desvio Corsan
# *** TERM ***
# Corral Quemado
# *** TERM ***
# Corral Quemado
# *** TERM ***
# Corrales
# *** TERM ***
# Canada Corral de Piedra
# *** TERM ***
# Bajo de Corral de Piedra
# *** TERM ***
# Departamento de Corpen Aike
# *** TERM ***
# Coronel Vidt
# *** TERM ***
# Coronel Hilario Lagos
# *** TERM ***
# Coronel Granada
# *** TERM ***
# Coronel Fraga
# *** TERM ***
# Estacion Coronel Charlone
# *** TERM ***
# Corrida de Cori
# *** TERM ***
# Morro los Cordoncitos
# *** TERM ***
# Estacion Corbett
# *** TERM ***
# Coquelen
# *** TERM ***
# Consuelo
# *** TERM ***
# Departamento de Constitucion
# *** TERM ***
# Cerro Conico Chico
# *** TERM ***
# Condorhuasi
# *** TERM ***
# Pico Condores
# *** TERM ***
# Cerro Condores
# *** TERM ***
# Portezuelo de Conconta
# *** TERM ***
# Compuel
# *** TERM ***
# Comando V Cuerpo Ejercito
# *** TERM ***
# Comandante Granville
# *** TERM ***
# Portezuelo Colorado
# *** TERM ***
# Pico Colorado
# *** TERM ***
# Cordon del Colorado
# *** TERM ***
# Cerro Colorado
# *** TERM ***
# Aguada Colorada
# *** TERM ***
# Colonia Udine
# *** TERM ***
# Lago Musters Airport
# *** TERM ***
# Colonia Santa Maria
# *** TERM ***
# Colonia Santa Elena
# *** TERM ***
# Colonia El Cisne
# *** TERM ***
# Colonia El Carmen
# *** TERM ***
# Colonia Butalo
# *** TERM ***
# Ensenada de la Colonia
# *** TERM ***
# Cerro Colon
# *** TERM ***
# Cabo Colnett
# *** TERM ***
# Jaguel Colmenares
# *** TERM ***
# Collon Cura
# *** TERM ***
# Colipilli
# *** TERM ***
# Arroyo Colgado Grande
# *** TERM ***
# Coehue-Co
# *** TERM ***
# Cerro Codihue
# *** TERM ***
# Mogote los Cocos
# *** TERM ***
# Departamento de Cochinoca
# *** TERM ***
# Cocha Vieja
# *** TERM ***
# Cerro Cochal
# *** TERM ***
# Cerro Cobres
# *** TERM ***
# Clucellas
# *** TERM ***
# Faro Claromeco
# *** TERM ***
# Cerro Clark
# *** TERM ***
# Chorrillo del Cisne
# *** TERM ***
# Cerros de los Cinco Picachos
# *** TERM ***
# Abra Cilinias
# *** TERM ***
# Punta Ciervos
# *** TERM ***
# Apeadero Cienaguita
# *** TERM ***
# Cienaguilla
# *** TERM ***
# Abra Cienaga Grande
# *** TERM ***
# Puesto Chusca
# *** TERM ***
# Churquipampa
# *** TERM ***
# Churcal
# *** TERM ***
# Chungango
# *** TERM ***
# Chunchico
# *** TERM ***
# Quebrada Chorro Blanco
# *** TERM ***
# Rio Chorrillos
# *** TERM ***
# Arroyo Chorrillo Los Vascos
# *** TERM ***
# Cerro Cholila
# *** TERM ***
# Pampa del Choique
# *** TERM ***
# Cerro Chohuecura
# *** TERM ***
# Chocoite
# *** TERM ***
# Pampa de los Chivos
# *** TERM ***
# Chivo Huete
# *** TERM ***
# Chivilme
# *** TERM ***
# Chivil
# *** TERM ***
# Arroyo Chitas
# *** TERM ***
# Pozo del Chirete
# *** TERM ***
# Cerro Chingolo
# *** TERM ***
# Arroyo China Muerta Mallin
# *** TERM ***
# Departamento de Chilecito
# *** TERM ***
# Chigua de Arriba
# *** TERM ***
# Cerro Chico del Cerro Colorado
# *** TERM ***
# Chicligasta
# *** TERM ***
# Pampa Chichahuay
# *** TERM ***
# Pampa Chica
# *** TERM ***
# Cumbre Chica
# *** TERM ***
# Arroyo Cherque
# *** TERM ***
# Rio Chavarria
# *** TERM ***
# Chaupi Pozo
# *** TERM ***
# Vega Chau
# *** TERM ***
# Cerro Chato
# *** TERM ***
# Punta Chata
# *** TERM ***
# Cerro Charlone
# *** TERM ***
# Quebrada de Charco
# *** TERM ***
# Aguada de las Charas
# *** TERM ***
# Charahuilla
# *** TERM ***
# Estancia Charabones
# *** TERM ***
# Cerro del Chancho
# *** TERM ***
# Chancay
# *** TERM ***
# Arroyo Chanas
# *** TERM ***
# Chanar Chico
# *** TERM ***
# Chanar Bajada
# *** TERM ***
# Champones
# *** TERM ***
# Arroyo Chalia Medio
# *** TERM ***
# Chacras de Ross
# *** TERM ***
# Chacra Andriani
# *** TERM ***
# Sierra de los Chacays
# *** TERM ***
# Arroyo Chacayquito
# *** TERM ***
# Chacay Melehue
# *** TERM ***
# Pozo del Cevit
# *** TERM ***
# Cerro Rico
# *** TERM ***
# Pampa de Cerro Piedra
# *** TERM ***
# Lomas del Cerro Negro
# *** TERM ***
# Estancia Cerro Fortaleza
# *** TERM ***
# Cerro Dragon
# *** TERM ***
# Estancia Cerro del Paso
# *** TERM ***
# Puesto Cerro Calderon
# *** TERM ***
# Quebrada del Cerro Blanco
# *** TERM ***
# Estancia Cerro Blanco
# *** TERM ***
# Estancia Cerro Bayo
# *** TERM ***
# Laguna del Cerrito
# *** TERM ***
# Agua de la Cerraja
# *** TERM ***
# Canal Centenario
# *** TERM ***
# Rio de los Cedros
# *** TERM ***
# Cebil Solo
# *** TERM ***
# Cebilar
# *** TERM ***
# Estancia C. Caamano
# *** TERM ***
# Cerro Cazador
# *** TERM ***
# Cazadero Grande
# *** TERM ***
# Canadon Catan Lil
# *** TERM ***
# Cerro Castillo
# *** TERM ***
# Cerro Castilla
# *** TERM ***
# Cerro Castellanos
# *** TERM ***
# Rio Castano Viejo
# *** TERM ***
# Cerro de los Castanos
# *** TERM ***
# Castano Nuevo
# *** TERM ***
# Cassaffousth
# *** TERM ***
# Quebrada Caspar
# *** TERM ***
# Casimiro Gomez
# *** TERM ***
# Canadon Casey
# *** TERM ***
# Cascada de Olaen
# *** TERM ***
# Casa Grande
# *** TERM ***
# Quebrada Casa de Piedra
# *** TERM ***
# Arroyo Casa de Piedra
# *** TERM ***
# Casa de Mingo
# *** TERM ***
# Casa Colorada
# *** TERM ***
# Casa Armada
# *** TERM ***
# Cerro Carrizo
# *** TERM ***
# Carrizal Seco
# *** TERM ***
# Carrizal de Arriba
# *** TERM ***
# Carrilobo
# *** TERM ***
# Medano la Carreta
# *** TERM ***
# Estancia Carreri
# *** TERM ***
# Cerro de la Carpa
# *** TERM ***
# Bajo de la Carpa
# *** TERM ***
# Estancia Carmenlao
# *** TERM ***
# Monte Carmelo
# *** TERM ***
# Estancia Carmelo
# *** TERM ***
# Carlos Maria Naon
# *** TERM ***
# Estancia Carilauquen
# *** TERM ***
# Banado del Cari-Lauquen
# *** TERM ***
# Arroyo Carico
# *** TERM ***
# Estancia Carhue
# *** TERM ***
# Estacion Carhue
# *** TERM ***
# Isla del Carbon
# *** TERM ***
# Carapacha
# *** TERM ***
# Cerro de los Caranchos
# *** TERM ***
# Carahuasi
# *** TERM ***
# Cerro de Caracol
# *** TERM ***
# Carachipampa
# *** TERM ***
# Estacion Capitan Montoya
# *** TERM ***
# Capilla de Siton
# *** TERM ***
# Cerro Diecinueve de Febrero
# *** TERM ***
# Cantina
# *** TERM ***
# Paso de las Canoas
# *** TERM ***
# Cangrejos
# *** TERM ***
# Cangrejillos
# *** TERM ***
# Serrania de las Canas
# *** TERM ***
# Estancia Canadon Salado
# *** TERM ***
# Canadon Perdido
# *** TERM ***
# Estancia Canadon Guitarra
# *** TERM ***
# Cerro Canadon de los Potros
# *** TERM ***
# Estancia Canadon Blanco
# *** TERM ***
# Puesto Canadas Duras
# *** TERM ***
# Canada Rosquin
# *** TERM ***
# Estancia Camusu Aike
# *** TERM ***
# Campos El Veinticinco
# *** TERM ***
# Isla Campo Rico
# *** TERM ***
# Campo Rayo
# *** TERM ***
# Campo Peyrano
# *** TERM ***
# Campo Moctezuma
# *** TERM ***
# Campo Los Angeles
# *** TERM ***
# Campo Duran
# *** TERM ***
# Campo de Vichigasta
# *** TERM ***
# Campo de Anchoco
# *** TERM ***
# Campo Canadon Grande
# *** TERM ***
# Campichuelo
# *** TERM ***
# Barda de las Campanas
# *** TERM ***
# Estancia Campamento Real
# *** TERM ***
# Chorrillo Campamento
# *** TERM ***
# Rio del Camino
# *** TERM ***
# Cerro Camino
# *** TERM ***
# Colonia Calzada
# *** TERM ***
# La Caldera
# *** TERM ***
# Rio Calchaqui
# *** TERM ***
# Arroyo del Cajon Grande
# *** TERM ***
# Cerro Cajon de Minas
# *** TERM ***
# Cajon de Almanza
# *** TERM ***
# Rio de Cajon
# *** TERM ***
# Morro Cajon
# *** TERM ***
# Cerro del Cajon
# *** TERM ***
# Cerro Cain
# *** TERM ***
# Cafayate
# *** TERM ***
# Cachiyuyo
# *** TERM ***
# Estancia Cachi-Yacu
# *** TERM ***
# Laguna Cabral
# *** TERM ***
# Cerro Cabezon
# *** TERM ***
# Arroyo de las Cabezas de Vacas
# *** TERM ***
# Cabeza de Vaca
# *** TERM ***
# Ex Fortin Cabeza de Chancho
# *** TERM ***
# Agua de los Caballos
# *** TERM ***
# Cerro de las Caballadas
# *** TERM ***
# Paso de Buta Mallin
# *** TERM ***
# Buta Mallin
# *** TERM ***
# Arroyo Butalo
# *** TERM ***
# Rio de los Burros
# *** TERM ***
# Loma de los Burros
# *** TERM ***
# Cajon de la Burra
# *** TERM ***
# Cerro de la Buitrera
# *** TERM ***
# Buena Esperanza
# *** TERM ***
# Laguna Buen Abrigo
# *** TERM ***
# Cerro del Bronce
# *** TERM ***
# Caleta Brightman
# *** TERM ***
# Brea Pozo
# *** TERM ***
# Bragado
# *** TERM ***
# Bowen
# *** TERM ***
# Estancia Boubet
# *** TERM ***
# Rio de Botegayoc
# *** TERM ***
# Bordo Pampa
# *** TERM ***
# Bordo del Arbolito
# *** TERM ***
# Bordo de la Cruz
# *** TERM ***
# Puesto Bordo Amarillo
# *** TERM ***
# Cerro Borax
# *** TERM ***
# Bajo Bonito
# *** TERM ***
# Cerro Bonete
# *** TERM ***
# Bajo de la Bomba
# *** TERM ***
# Bolsa Ura
# *** TERM ***
# Morro de la Bolsa
# *** TERM ***
# Canadon Boliche
# *** TERM ***
# Cerro Bola
# *** TERM ***
# Bodeguita
# *** TERM ***
# Paso Boca Santa Rosa
# *** TERM ***
# Cerro Blancutre
# *** TERM ***
# Arroyo Blanco Sur
# *** TERM ***
# Portezuelo de los Blancos
# *** TERM ***
# Cerro Blanco
# *** TERM ***
# Cerrito Blanco
# *** TERM ***
# Puesto Bitzch
# *** TERM ***
# Estancia Bienvenida
# *** TERM ***
# Canadon Beta
# *** TERM ***
# Pampa del Bermejo
# *** TERM ***
# Canal Bermejo
# *** TERM ***
# Benjamin Gould
# *** TERM ***
# Lagunas del Benito
# *** TERM ***
# Benando
# *** TERM ***
# Bellocq
# *** TERM ***
# Almacen Belgrano
# *** TERM ***
# Beas
# *** TERM ***
# Chacra B Casac
# *** TERM ***
# Arroyo de los Bayos
# *** TERM ***
# Loma Baya
# *** TERM ***
# Baudrix
# *** TERM ***
# Cerro Bastion
# *** TERM ***
# Cabo Base Bahia
# *** TERM ***
# Barro Negro
# *** TERM ***
# Barrio del Panal
# *** TERM ***
# Barrio Cuidad Atlantida
# *** TERM ***
# Canadon Barril
# *** TERM ***
# Altiplano Barreras Blancas
# *** TERM ***
# Cerro del Barranquino
# *** TERM ***
# Quebrada Barrancas
# *** TERM ***
# Cerro Barrancas
# *** TERM ***
# Abra de Barrancas
# *** TERM ***
# Barrancas
# *** TERM ***
# Cerro de las Bardas
# *** TERM ***
# Punta de la Barda
# *** TERM ***
# Paso de Barahona
# *** TERM ***
# Banos Termales
# *** TERM ***
# Banos del Cerro
# *** TERM ***
# Banos
# *** TERM ***
# Arroyo Banderas
# *** TERM ***
# Banado de Soto
# *** TERM ***
# Banadero
# *** TERM ***
# Isla Ballesteros
# *** TERM ***
# Balde de Quesada
# *** TERM ***
# Balcarce
# *** TERM ***
# Bajos de Correa
# *** TERM ***
# Bajo Lindo
# *** TERM ***
# Estancia Bajo Hondo
# *** TERM ***
# Canadon Bajo Hondo
# *** TERM ***
# Bajo Hondo
# *** TERM ***
# Estancia Bajo Fuego
# *** TERM ***
# Bajo de Velis
# *** TERM ***
# Bajada Inti
# *** TERM ***
# Estancia Bajada de los Orientales
# *** TERM ***
# Estancia Bahia Langara
# *** TERM ***
# Esturaio de la Bahia Blanca
# *** TERM ***
# Pozo del Bagual
# *** TERM ***
# Cerro Bachongo
# *** TERM ***
# Cerro los Azules
# *** TERM ***
# Arroyo Ayunchal
# *** TERM ***
# Cerro Ayosh
# *** TERM ***
# Arroyo Aviles
# *** TERM ***
# Puesto del Avestruz
# *** TERM ***
# Avestruz
# *** TERM ***
# Averias
# *** TERM ***
# Estancia Ave Maria
# *** TERM ***
# Peninsula Avellaneda
# *** TERM ***
# Portezuelo de Auquinco
# *** TERM ***
# Cerro Atreuco
# *** TERM ***
# Cerro Atravesado
# *** TERM ***
# Abra de Atacamara
# *** TERM ***
# Paso de Atacalco
# *** TERM ***
# Rio Astillero
# *** TERM ***
# Cerro el Aspero
# *** TERM ***
# Punta Asconape
# *** TERM ***
# Canadon Artilleros
# *** TERM ***
# Arroyo Seco
# *** TERM ***
# Aromito
# *** TERM ***
# Armstrong
# *** TERM ***
# Peninsula Aristizabal
# *** TERM ***
# Desvio Arijon
# *** TERM ***
# Bajo Arido
# *** TERM ***
# Mina Argentina
# *** TERM ***
# Arenaza
# *** TERM ***
# Arcor
# *** TERM ***
# Paso del Arco Norte
# *** TERM ***
# Vega Archibarca
# *** TERM ***
# Canada de Arce
# *** TERM ***
# Arbolitos
# *** TERM ***
# Arboles del Gallo
# *** TERM ***
# Puesto Arboles Blancos
# *** TERM ***
# Arbol Blanco
# *** TERM ***
# Estancia Aranda
# *** TERM ***
# Estancia Arana
# *** TERM ***
# Cerro Aqui Hueco
# *** TERM ***
# Estancia A. Paz
# *** TERM ***
# Sierra Apas
# *** TERM ***
# Sierra Anueque
# *** TERM ***
# Apeadero Antonio E. Talbot
# *** TERM ***
# Puesto Antiguo
# *** TERM ***
# Cerro de Antigual
# *** TERM ***
# Rio de Ansilta
# *** TERM ***
# Animana
# *** TERM ***
# Cerro Angostura
# *** TERM ***
# Angostura
# *** TERM ***
# Andrade
# *** TERM ***
# Quebrada Ancha
# *** TERM ***
# Departamento de Ancasti
# *** TERM ***
# Ancajuli
# *** TERM ***
# Ana Zumaran
# *** TERM ***
# Cerro Ampisa
# *** TERM ***
# Estancia Amonguyra
# *** TERM ***
# Ambil
# *** TERM ***
# Loma Amarilla
# *** TERM ***
# Rio Amanao
# *** TERM ***
# Amalia
# *** TERM ***
# Rio Amaicha
# *** TERM ***
# Arroyo Amadores
# *** TERM ***
# Bajo de Alzula
# *** TERM ***
# Estancia Alvarez
# *** TERM ***
# Aguada Alumbre
# *** TERM ***
# Alto Rio Mayo
# *** TERM ***
# Altohuasi
# *** TERM ***
# Alto de Medina
# *** TERM ***
# Cerro Alto Chacaico
# *** TERM ***
# Sierra Alta de Zonda
# *** TERM ***
# Punta Alta
# *** TERM ***
# Meseta Alta
# *** TERM ***
# Laguna del Aljibe
# *** TERM ***
# Canal Aliviador Eustolia
# *** TERM ***
# Puesto Alinco
# *** TERM ***
# Algarrobo del Aguila
# *** TERM ***
# Cerrito del Algarrobo
# *** TERM ***
# Algarrobo
# *** TERM ***
# Alemania
# *** TERM ***
# Alejitos Ampa
# *** TERM ***
# Estacion Alejandro
# *** TERM ***
# Cerro Alejandro
# *** TERM ***
# Aldea Kranevitter
# *** TERM ***
# Aldea El Chaleco
# *** TERM ***
# Aldea Cuatro Casas
# *** TERM ***
# Alcira
# *** TERM ***
# Rio Albigasta
# *** TERM ***
# Cerro Alba del Mirador
# *** TERM ***
# Puesto Alameda
# *** TERM ***
# Loma Aji
# *** TERM ***
# Aimogasta
# *** TERM ***
# Aicuna
# *** TERM ***
# Arroyo Aguja
# *** TERM ***
# Bahia Aguirre
# *** TERM ***
# Aguilares
# *** TERM ***
# Quebrada de las Aguas Negras
# *** TERM ***
# Aguas de Palacio
# *** TERM ***
# Estacion Aguara
# *** TERM ***
# Cumbre Agua Negra
# *** TERM ***
# Cordillera Agua Negra
# *** TERM ***
# Agua Hedionda
# *** TERM ***
# Agua del Sauce
# *** TERM ***
# Agua del Rio
# *** TERM ***
# Puesto del Agua de los Patos
# *** TERM ***
# Agua de las Palomas
# *** TERM ***
# Cordon de Aguada Salada
# *** TERM ***
# Aguada Nueva
# *** TERM ***
# Aguada del Zaino
# *** TERM ***
# Cerro Aguada del Matrero
# *** TERM ***
# Puesto Aguada del Hueso
# *** TERM ***
# Estancia Aguada del Cuero
# *** TERM ***
# Aguada de Chacay
# *** TERM ***
# Puesto Aguada
# *** TERM ***
# Agua Colorada
# *** TERM ***
# Agua Buena
# *** TERM ***
# Aerolito
# *** TERM ***
# Estancia Adela
# *** TERM ***
# Achico
# *** TERM ***
# Cerro Achi
# *** TERM ***
# Rio Acequion
# *** TERM ***
# Acebal
# *** TERM ***
# Acazoque
# *** TERM ***
# Cerro Abra Quesera
# *** TERM ***
# Cerro Tralihue
# *** TERM ***
# Paso Agua de la Falda
# *** TERM ***
# Laguna Chosoico
# *** TERM ***
# Punta Pehuenco
# *** TERM ***
# Fronton Gable
# *** TERM ***
# Bahia Almirante Brown
# *** TERM ***
# Punta Maria
# *** TERM ***
# Roca Santa Cruz
# *** TERM ***
# Rotura del Colorado
# *** TERM ***
# Baliza Cerro Prismatico
# *** TERM ***
# Avenida Circunvalacion
# *** TERM ***
# Sanatorio Parque
# *** TERM ***
# Centro Cultural Antartida Argentina
# *** TERM ***
# Liceo Aeronautico Militar De Funes
# *** TERM ***
# Paseo Del Caminante
# *** TERM ***
# Parque Mitre ("Las Cuatro Plazas")
# *** TERM ***
# Isla Corazon ( Piuque)
# *** TERM ***
# Sauce Viejo Airport
# *** TERM ***
# Teniente General Benjamin Matienzo International Airport
# *** TERM ***
# Posadas Airport
# *** TERM ***
# Oran Airport
# *** TERM ***
# Hyde Park
# *** TERM ***
# El Conquistador Hotel
# *** TERM ***
# Nido del Condor Resort & Spa
# *** TERM ***
# Sheraton Pilar Hotel and Convention Center
# *** TERM ***
# Dazzler Hotel Bariloche
# *** TERM ***
# PARK HYATT MENDOZA
# *** TERM ***
# Reconquista Plaza
# *** TERM ***
# Sofitel Buenos Aires
# *** TERM ***
# Howard Johnson Hotel Da Vinci
# *** TERM ***
# Abasto Plaza Hotel
# *** TERM ***
# Amerian Buenos Aires Park Hotel
# *** TERM ***
# Four Seasons Buenos Aires
# *** TERM ***
# Sarmiento Suites Apart Hotel
# *** TERM ***
# Bella Vista De Guerrero
# *** TERM ***
# Hotel Francia
# *** TERM ***
# La China Casa De Campo
# *** TERM ***
# Ulises Recoleta Suites
# *** TERM ***
# Hotel Bel Air
# *** TERM ***
# Hotel La Merced
# *** TERM ***
# Hotel Salles
# *** TERM ***
# La Reduccion de Santa Ana
# *** TERM ***
# Ischigualasto Natural Park
# *** TERM ***
# Aguas Verdes
# *** TERM ***
# Rivadavia y Sgo. del Estero, SFE
# *** TERM ***
# Blas Parera y Castelli, SFE
# *** TERM ***
# Av. Del Valle y J. de la Rosa
# *** TERM ***
# 7 de Marzo e Iriondo, STO. TOME
# *** TERM ***
# R19 y AT Sfe-Rosario, STO. TOME
# *** TERM ***
# Av. del Valle y L. Torrent, SFE
# *** TERM ***
# Acceso a San Carlos
# *** TERM ***
# axel buenos aires
# *** TERM ***
# b a city
# *** TERM ***
# dazzler tower san martin
# *** TERM ***
# esplendor palermo
# *** TERM ***
# kelta
# *** TERM ***
# solanas playa mar del plata
# *** TERM ***
# urquiza apart hotel suites
# *** TERM ***
# wilson
# *** TERM ***
# forcadell libertador
# *** TERM ***
# purobaires hotel boutique
# *** TERM ***
# villa sofia resort and spa
# *** TERM ***
# alkazar hotel
# *** TERM ***
# alma de buenos aires hotel boutique
# *** TERM ***
# apart hotel bosch
# *** TERM ***
# apart sures belgrano suites
# *** TERM ***
# apart urbana suites
# *** TERM ***
# bristol condominio apart hotel
# *** TERM ***
# cabanas don david
# *** TERM ***
# cacique inacayal grand boutique
# *** TERM ***
# correntoso lake and amp riv
# *** TERM ***
# costa rio apart hotel
# *** TERM ***
# cristal
# *** TERM ***
# del jardin hotel
# *** TERM ***
# ducal suites hotel
# *** TERM ***
# ecuador hotel
# *** TERM ***
# edificio piccaluga
# *** TERM ***
# el corazon de la bahia
# *** TERM ***
# fantilli hotel
# *** TERM ***
# finca los alamos
# *** TERM ***
# garden hotel rosario
# *** TERM ***
# general guemes hotel
# *** TERM ***
# hostal del bosque
# *** TERM ***
# hotel ancasti
# *** TERM ***
# hotel del sol
# *** TERM ***
# hotel provincial mendoza
# *** TERM ***
# Santa Fe Avenue
# *** TERM ***
# howard johnson hotel boutique recoleta
# *** TERM ***
# howard johnson inn v gral belgrano
# *** TERM ***
# jam suites boutique hotel
# *** TERM ***
# lancuyen villa de montana
# *** TERM ***
# maro hotel
# *** TERM ***
# obelisco center suites
# *** TERM ***
# own hotel
# *** TERM ***
# panamericano
# *** TERM ***
# patios de lerma hotel
# *** TERM ***
# pinamar resort
# *** TERM ***
# presidente hotel bariloche
# *** TERM ***
# provincial hotel rawson
# *** TERM ***
# regal pacific buenos aires
# *** TERM ***
# ribera sur hotel
# *** TERM ***
# san antonio hotel
# *** TERM ***
# san lorenzo apartments
# *** TERM ***
# san remo viking hotel
# *** TERM ***
# solares cumbrecita hotel
# *** TERM ***
# the migueletes plaza
# *** TERM ***
# america del sur hostel
# *** TERM ***
# argenta tower hotel suites
# *** TERM ***
# cristal palace
# *** TERM ***
# linda vista apart hotel
# *** TERM ***
# Columbia Palace
# *** TERM ***
# Plaza San Martin Tower S.A.
# *** TERM ***
# Urban Suites Recoleta Boutique Hotel
# *** TERM ***
# Las Lenas
# *** TERM ***
# Los Arrayanes National Park
# *** TERM ***
# Plaza Italia (Buenos Aires)
# *** TERM ***
# Los Castores
# *** TERM ***
# Palacio del Congreso de la Nacion Argentina
# *** TERM ***
# Centro de Ski La Hoya
# *** TERM ***
# Colonia Catriel Airport
# *** TERM ***
# Mercedes Airport
# *** TERM ***
# Olavarria Airport
# *** TERM ***
# La Cienaga
# *** TERM ***
# Hotel Intercontinental
# *** TERM ***
# Lago Puelo (pueblo)
# *** TERM ***
# Escuela Cuarenta y Seis
# *** TERM ***
# B. Reniero
# *** TERM ***
# L. Alves
# *** TERM ***
# J. Chipilu
# *** TERM ***
# Estancia Ferre
# *** TERM ***
# Almacen Torres
# *** TERM ***
# E. Flores
# *** TERM ***
# Arroyo Gil
# *** TERM ***
# Puesto Porton Colorado
# *** TERM ***
# Chacra J. Sogica
# *** TERM ***
# Almacen San Ramon
# *** TERM ***
# Dupont
# *** TERM ***
# Azorin
# *** TERM ***
# J. Tisocco
# *** TERM ***
# Maidano
# *** TERM ***
# A. Galli
# *** TERM ***
# Estancia L. Surt
# *** TERM ***
# Arroyo Aguara Guazu
# *** TERM ***
# Brunini
# *** TERM ***
# P. Jesus
# *** TERM ***
# Viuda de Caprioti
# *** TERM ***
# A. Sarafino
# *** TERM ***
# Listani
# *** TERM ***
# E. Harchimberbe
# *** TERM ***
# P. Velo
# *** TERM ***
# Sguerzo
# *** TERM ***
# Puesto Los Huncales
# *** TERM ***
# Canada Vizcachera
# *** TERM ***
# F. Francisconi
# *** TERM ***
# Estancia Russo
# *** TERM ***
# G. Kriguer
# *** TERM ***
# I. Lugrin
# *** TERM ***
# O. F. Silva
# *** TERM ***
# C. Sinier
# *** TERM ***
# Almacen Droz
# *** TERM ***
# Puesto La Reserva
# *** TERM ***
# M. Schneider
# *** TERM ***
# S.P. Benitez
# *** TERM ***
# Cremeria
# *** TERM ***
# E. Yenta
# *** TERM ***
# Chacra Diaz Velez
# *** TERM ***
# F. Bouvet
# *** TERM ***
# P. Soldera
# *** TERM ***
# J. Ramat
# *** TERM ***
# Bche. Sierra Gimenez
# *** TERM ***
# Iglesia Nuestra Senora del La Paz
# *** TERM ***
# Arroyo Caraballo Chico
# *** TERM ***
# Caviahue
# *** TERM ***
# Departamento de Tafi del Valle
# *** TERM ***
# Departamento de Tafi Viejo
# *** TERM ***
# Departamento de Dos de Abril
# *** TERM ***
# Departamento de Islas del Ibicuy
# *** TERM ***
# Departamento de Juan B. Alberdi
# *** TERM ***
# General Alvear Airport
# *** TERM ***
# Club Medico
# *** TERM ***
# Bonpland
# *** TERM ***
# Rio Segundo
# *** TERM ***
# Rio Suquia
# *** TERM ***
# Centuria
# *** TERM ***
# Hotel Pulitzer Buenos Aires
# *** TERM ***
# Eurobuilding Hotel Boutique Buenos Aires
# *** TERM ***
# Facon Grande
# *** TERM ***
# Hotel Asturias
# *** TERM ***
# Dazzler Laprida Hotel
# *** TERM ***
# Dumont Hotel
# *** TERM ***
# Olmo Dorado Business Hotel & Urban Spa
# *** TERM ***
# Territorio Puerto Madryn
# *** TERM ***
# Australis Yenehue Hotel Y Spa
# *** TERM ***
# Merit Majestic Hotel Rosario
# *** TERM ***
# Don Enrique Lodge
# *** TERM ***
# Blumig Hotel
# *** TERM ***
# Gran Hotel Cristal
# *** TERM ***
# Las Bayas Hotel
# *** TERM ***
# Lennox
# *** TERM ***
# Alto Rosario Shopping Mall
# *** TERM ***
# Hotel Chipre
# *** TERM ***
# Palo Santo Hotel
# *** TERM ***
# Costa Rica Hotel
# *** TERM ***
# Unique Art Elegance
# *** TERM ***
# Buenos Aires Grand Hotel Recol
# *** TERM ***
# Vibes Music Hotel
# *** TERM ***
# Centro Naval
# *** TERM ***
# Apart Costa Azul
# *** TERM ***
# Grand Crucero Hotel
# *** TERM ***
# Livin Residence
# *** TERM ***
# Le Village
# *** TERM ***
# Terrazas De Mar
# *** TERM ***
# Paraje De Almas
# *** TERM ***
# Arenales Apartments And Suites
# *** TERM ***
# Hotel Premier
# *** TERM ***
# Shauard
# *** TERM ***
# Palacio Chic Boutique Hotel
# *** TERM ***
# Polo Suites By Hollywood
# *** TERM ***
# Le Vitral Baires Boutique Hotel
# *** TERM ***
# Hr Luxor
# *** TERM ***
# Nutibara
# *** TERM ***
# Cabanas Del Lenador
# *** TERM ***
# Los Juncos Patagonian Lake House
# *** TERM ***
# Defensa Suites By Temporary Apartments
# *** TERM ***
# Raices Aconcagua
# *** TERM ***
# Barisit House Hotel
# *** TERM ***
# Alpasion Lodge
# *** TERM ***
# Alto Parana
# *** TERM ***
# Apts Atenea Suites
# *** TERM ***
# Australis Campana
# *** TERM ***
# Grace Cafayate
# *** TERM ***
# Algodon Mansion
# *** TERM ***
# Del Bono Suites
# *** TERM ***
# Del Bono Beach
# *** TERM ***
# Gran Hotel Panamericano Mar Del Plata
# *** TERM ***
# Puerto Canoas
# *** TERM ***
# Plaza Paradiso Petit Hotel
# *** TERM ***
# Magnolia Hotel Boutique
# *** TERM ***
# Lecer Apart
# *** TERM ***
# Palermo Soho Loft
# *** TERM ***
# Bobo Hotel And Restaurant
# *** TERM ***
# Eco Pampa Hostel
# *** TERM ***
# Paradores Austral Bahia Blanca
# *** TERM ***
# Carlos V
# *** TERM ***
# Iris
# *** TERM ***
# Milonga Guest House
# *** TERM ***
# Grand Hotel Dora
# *** TERM ***
# Ba City Residencial Bed and Breakfast
# *** TERM ***
# Isla Volantin
# *** TERM ***
# Bahia Blanca
# *** TERM ***
# Camping Municipal Arenas Blancas
# *** TERM ***
# El Timbo
# *** TERM ***
# Hito Punto (Piedra) Accesible Treinta y Cinco de La Triangulacion Argentina
# *** TERM ***
# Hito Portezuelo del Castillo
# *** TERM ***
# Cerro Baya de Cori
# *** TERM ***
# Hito XXVIII
# *** TERM ***
# Hito XXIX
# *** TERM ***
# Estancia La Paula
# *** TERM ***
# Estancia Juana Elena
# *** TERM ***
# Barrio Puente Ezcurra
# *** TERM ***
# La Bavaria
# *** TERM ***
# Estancia San Rufino
# *** TERM ***
# Estancia San Niall
# *** TERM ***
# Villa Gregoria Matorras
# *** TERM ***
# Laguna Idahome
# *** TERM ***
# Barrio Marabo
# *** TERM ***
# Estancia Los Castanos
# *** TERM ***
# El Morejon
# *** TERM ***
# Puerto Parana
# *** TERM ***
# Hosteria Atelier
# *** TERM ***
# Isla Yacht Club Argentino
# *** TERM ***
# Estacion Ingeniero Budge
# *** TERM ***
# Ciudad General Martin Miguel de Gueemes
# *** TERM ***
# Estacion Liniers
# *** TERM ***
# Parada Capitan Lozano
# *** TERM ***
# Arroyo El Pobre
# *** TERM ***
# Estacion Llavallol
# *** TERM ***
# Tambo La Maria
# *** TERM ***
# Tambo J. Casaubon
# *** TERM ***
# Canal Garcia
# *** TERM ***
# Arroyo Rama Negra
# *** TERM ***
# Barrio Grossville
# *** TERM ***
# Villa Siglo XX
# *** TERM ***
# Estacion General Sarmiento
# *** TERM ***
# Puente Marquez
# *** TERM ***
# Puente Falbu
# *** TERM ***
# Rio Barca Grande
# *** TERM ***
# Estancia La Canderlaria
# *** TERM ***
# Estancia La Liebre
# *** TERM ***
# Estancia La Fidelita
# *** TERM ***
# Arroyo Las Garzas
# *** TERM ***
# Arroyo Las Lagunas
# *** TERM ***
# Arroyo Union
# *** TERM ***
# Arroyo Come Vaca
# *** TERM ***
# Tambo A. Basilio
# *** TERM ***
# Chacra Sucursal D. Etchart
# *** TERM ***
# Tambo A. de Busso
# *** TERM ***
# Chacra D. De Curtis
# *** TERM ***
# Puente Nino
# *** TERM ***
# Tambo B. Fourcade
# *** TERM ***
# Tambo Los Mellizos
# *** TERM ***
# Tambo J. Amantegui
# *** TERM ***
# Estancia G. Lorenzetti
# *** TERM ***
# Tambo D. Harluchete
# *** TERM ***
# Tambo J. Irigoyen
# *** TERM ***
# Tambo G. Saldubehere
# *** TERM ***
# Arroyo Tarapuati
# *** TERM ***
# Estacion Rio Lujan
# *** TERM ***
# Estancia Canetti
# *** TERM ***
# Hito XXV
# *** TERM ***
# Hito Portezuelo Vidal Gormaz
# *** TERM ***
# Hito Paso de Pena Negra
# *** TERM ***
# Hito Paso de Pircas Negras
# *** TERM ***
# Hito XIV - Diez Paso de Potrerillos
# *** TERM ***
# Hito XIV - Once Paso Origen del Rio Potrerillos
# *** TERM ***
# Hito XIV - Doce Paso de los Amarillos
# *** TERM ***
# Hito XIII - Treinta Paso de Palacios
# *** TERM ***
# Llao Llao
# *** TERM ***
# Hito II-XVIII
# *** TERM ***
# Laguna del Roble
# *** TERM ***
# Hito XII-Once Portezuelo de Lomas Coloradas
# *** TERM ***
# Hito XII-Veinte Paso de La Honda
# *** TERM ***
# Hito XII-Veintiseis Portezuelo de Quebrada Grande
# *** TERM ***
# Hito XI-Treinta y Uno Paso de Molina
# *** TERM ***
# Hito XI-Cuarenta Paso de Alvarado (Norte)
# *** TERM ***
# Hito III-Veintisiete
# *** TERM ***
# Hito III-Veintiuno Vega Mala
# *** TERM ***
# Hito III-Diecinueve Dorotea Numero Dos
# *** TERM ***
# Cerro Pietrobelli
# *** TERM ***
# Hito III-Treinta y Cinco (Testigo) Arroyo Zanja Honda
# *** TERM ***
# Hito IV-Cero-B
# *** TERM ***
# Hito IV-Siete (Sesenta) Vuelta del Rio Mayer Orilla Norte
# *** TERM ***
# Comuna 12
# *** TERM ***
# Comuna 4
# *** TERM ***
# Chacarita
# *** TERM ***
# Saavedra
# *** TERM ***
# Villa Lugano
# *** TERM ***
# Nueva Pompeya
# *** TERM ***
# Monte Castro
# *** TERM ***
# Villa Devoto
# *** TERM ***
# Ramallo
# *** TERM ***
# Puerto Ibicuy
# *** TERM ***
# Mount Pleasant
# *** TERM ***
# Barrio Kaleuche
# *** TERM ***
# Balizar Edificio
# *** TERM ***
# Muelle General Mosconi
# *** TERM ***
# San Pedro Bar
# *** TERM ***
# Arroyo La Cruz
# *** TERM ***
# Boya Km. 30.4
# *** TERM ***
# Canal Marquez
# *** TERM ***
# Boya Km. 89.5
# *** TERM ***
# Faro Isla Martillo
# *** TERM ***
# Isla Rabbit
# *** TERM ***
# Green Pond
# *** TERM ***
# White Beacon (historical)
# *** TERM ***
# Old Nicolas Avellaneda Transporter Bridge
# *** TERM ***
# Hito VII-Diez (Doce)
# *** TERM ***
# Hito VIII-Ocho B
# *** TERM ***
# Hito VIII-Siete
# *** TERM ***
# Hito VIII-Veintiseis Camino de Pirehueico
# *** TERM ***
# Hito VIII-Veinte Portezuelo de Cajon Negro
# *** TERM ***
# Cordon Filicura
# *** TERM ***
# Hito IX-Diecisiete Paso de Coloco
# *** TERM ***
# Hito IX-Tres Paso Carirrine
# *** TERM ***
# Hito IX-Uno Portezuelo de Quelguenco
# *** TERM ***
# Hito IX-Treinta y Cuatro Portezuelo Sin Nombre
# *** TERM ***
# Hito IX-Veintiuno Paso de Icalma
# *** TERM ***
# Benedetti Seguros
# *** TERM ***
# Hito X-Cuarenta y Cuatro Paso El Portillo
# *** TERM ***
# Hito X-Veinticinco Paso Chureo
# *** TERM ***
# Hito X-Veintitres Paso de Pajaritos
# *** TERM ***
# Hito XI-Veintidos Paso del Planchon
# *** TERM ***
# Hito XI-Veintiuno Paso del Desecho
# *** TERM ***
# Hito XI-Ocho Paso Cajon Chico
# *** TERM ***
# Proyecto Caraya
# *** TERM ***
# Boya Km.77
# *** TERM ***
# Boya Km.52 (Red)
# *** TERM ***
# Boya No 32 (Km.112.7)
# *** TERM ***
# Boya Par No 27 (Km.128.1 Green)
# *** TERM ***
# Boya Par No 27 (Km.128.1 Red)
# *** TERM ***
# Boya Par No 16 (Km.158 Green)
# *** TERM ***
# Boya Par No 14 (Km.164 Green)
# *** TERM ***
# Boya Par No 10 (Km.174.3 Red)
# *** TERM ***
# Boya Par No 9 (Km.177 Green)
# *** TERM ***
# Ibicuy Wharf (historical)
# *** TERM ***
# Bajada Grande Wharf
# *** TERM ***
# Titan Crane North (historical)
# *** TERM ***
# Muelle Profertil
# *** TERM ***
# Dina Huapi
# *** TERM ***
# Villa Lago Meliquina
# *** TERM ***
# Santa Victoria Este
# *** TERM ***
# El Juncal
# *** TERM ***
# Pico Salado
# *** TERM ***
# Puerto San Julian
# *** TERM ***
# Hito XVI-Veinticinco
# *** TERM ***
# Hito XVI-Veinticuatro A
# *** TERM ***
# Lagunas de Pampa Cienaga
# *** TERM ***
# Lago Electrico
# *** TERM ***
# Bahia Tunel
# *** TERM ***
# Sogi
# *** TERM ***
# Afulei
# *** TERM ***
# Afimuao Stream
# *** TERM ***
# Agapie Cove
# *** TERM ***
# Alatele Cove
# *** TERM ***
# Amaluia
# *** TERM ***
# American Samoa Community College
# *** TERM ***
# Anapeapea Cove
# *** TERM ***
# Amuula Rock
# *** TERM ***
# Atauloma Stream
# *** TERM ***
# Atu'u
# *** TERM ***
# Audii Stream
# *** TERM ***
# Auvaiola Stream
# *** TERM ***
# Avaio
# *** TERM ***
# Vava Cove
# *** TERM ***
# Vaoaga Point
# *** TERM ***
# Vaisa Stream
# *** TERM ***
# Faalagiumu Point
# *** TERM ***
# Vailoloaitiiti Cove
# *** TERM ***
# Fagalea Point
# *** TERM ***
# Vaialufai Stream
# *** TERM ***
# Ututafa Point
# *** TERM ***
# Saililagi Ridge
# *** TERM ***
# Sinapoto Point
# *** TERM ***
# Si'ulagi
# *** TERM ***
# Utumea
# *** TERM ***
# Utuloa
# *** TERM ***
# Utulei Beach Park
# *** TERM ***
# Tuigaava Ridge
# *** TERM ***
# Tula
# *** TERM ***
# Tuafanua (historical)
# *** TERM ***
# Falaseeitoafa Point
# *** TERM ***
# Taufusitele Marsh
# *** TERM ***
# Taputimu
# *** TERM ***
# Tapua Stream
# *** TERM ***
# Tainamu Point
# *** TERM ***
# Tafola Rocks
# *** TERM ***
# Fatuana Point
# *** TERM ***
# Fatutea Spring
# *** TERM ***
# Fagasa Point
# *** TERM ***
# Failolo
# *** TERM ***
# Filiae Mountain
# *** TERM ***
# KSBS-FM (Pago Pago)
# *** TERM ***
# Lausaa Stream
# *** TERM ***
# Leala Point
# *** TERM ***
# Leanaopou Point
# *** TERM ***
# Lealafaalava Mountain
# *** TERM ***
# Leopard Point
# *** TERM ***
# Lauliituai
# *** TERM ***
# Leone
# *** TERM ***
# Lepua Point
# *** TERM ***
# Lepula (historical)
# *** TERM ***
# Leutu Point
# *** TERM ***
# Malaetia Stream
# *** TERM ***
# Luamaa (historical)
# *** TERM ***
# Malaeloa/Ituau
# *** TERM ***
# Maatulaumea Point
# *** TERM ***
# Malagateine Stream
# *** TERM ***
# Masefau Elementary School
# *** TERM ***
# Manu'a High School
# *** TERM ***
# Masausi
# *** TERM ***
# Mulimauga Ridge
# *** TERM ***
# Matavai Point
# *** TERM ***
# Mauga o Ali'i
# *** TERM ***
# Nuuosina Rock
# *** TERM ***
# Goat Island Point
# *** TERM ***
# Niuaveve Rock
# *** TERM ***
# Nuuomanu Rock
# *** TERM ***
# Nuututai Rock
# *** TERM ***
# Ofu Island
# *** TERM ***
# Oloava Crater
# *** TERM ***
# Olomatimu Crater
# *** TERM ***
# Pago Pago Elementary School
# *** TERM ***
# Pisiula Point
# *** TERM ***
# Pava'ia'i Elementary School
# *** TERM ***
# Pofala Hill
# *** TERM ***
# Village of Afao
# *** TERM ***
# Village of Amanave
# *** TERM ***
# Village of Amaua
# *** TERM ***
# Village of Aoa
# *** TERM ***
# Village of Ili'ili
# *** TERM ***
# Village of Mapusagafou
# *** TERM ***
# Village of Matu'u
# *** TERM ***
# Village of Onenoa
# *** TERM ***
# Village of Si'ufaga
# *** TERM ***
# Village of Utumea East
# *** TERM ***
# Federeck
# *** TERM ***
# Schuerhuette
# *** TERM ***
# Kleiner
# *** TERM ***
# Patzlberg
# *** TERM ***
# Totenkogel
# *** TERM ***
# Koenigin
# *** TERM ***
# Freitgraben
# *** TERM ***
# Hotel Bischofsberg
# *** TERM ***
# Hieflerstutzen
# *** TERM ***
# Stacherlhuette
# *** TERM ***
# Zottensberg
# *** TERM ***
# Goesswein
# *** TERM ***
# Pieglmoos
# *** TERM ***
# Alpsteig
# *** TERM ***
# Polzalm
# *** TERM ***
# Mausmayr
# *** TERM ***
# Lieblscharte
# *** TERM ***
# Schoberer
# *** TERM ***
# Grabnertorl
# *** TERM ***
# Volkernotgraben
# *** TERM ***
# ...
# Zensbauer
# *** TERM ***
# Zelko
# *** TERM ***
# Zeitlbach
# *** TERM ***
# Zeiselhof
# *** TERM ***
# Zeiselberg
# *** TERM ***
# Zeining
# *** TERM ***
# Zeil
# *** TERM ***
# Zeil
# *** TERM ***
# Zeierling
# *** TERM ***
# Zehnerkarspitze
# *** TERM ***
# Zaya
# *** TERM ***
# Zammelsberg
# *** TERM ***
# Zagel Kogel
# *** TERM ***
# Zacherled
# *** TERM ***
# Wurzerkampl
# *** TERM ***
# Wurzen
# *** TERM ***
# Burg
# *** TERM ***
# Worth
# *** TERM ***
# Wollmersdorf
# *** TERM ***
# Woellersdorf
# *** TERM ***
# Wollanig
# *** TERM ***
# Wolfshoferamt
# *** TERM ***
# Wolfsegg
# *** TERM ***
# Wolfgangalm
# *** TERM ***
# Wolfenreith
# *** TERM ***
# Monte Volaia
# *** TERM ***
# Wohlfahrtnergut
# *** TERM ***
# Wohlfahrt
# *** TERM ***
# Woegersdorf
# *** TERM ***
# Woebring
# *** TERM ***
# Wipfl
# *** TERM ***
# Wipfing
# *** TERM ***
# Winnebach
# *** TERM ***
# Windisch Grutschen
# *** TERM ***
# Windische Hoehe
# *** TERM ***
# Windischdorf
# *** TERM ***
# Windischbuehel
# *** TERM ***
# Windhagkogel
# *** TERM ***
# Windegg
# *** TERM ***
# Windbichl
# *** TERM ***
# Wimpassing im Schwarzatale
# *** TERM ***
# Wimberg
# *** TERM ***
# Wilhering
# *** TERM ***
# Wilhelmsburg
# *** TERM ***
# Wilfleinsdorf
# *** TERM ***
# Wildmoosalpe
# *** TERM ***
# Wildkarspitze
# *** TERM ***
# Wildgerlostal
# *** TERM ***
# Cima Libera
# *** TERM ***
# Wildenau
# *** TERM ***
# Wildbichl
# *** TERM ***
# Wiesacker
# *** TERM ***
# Wienering
# *** TERM ***
# Wienerbruck
# *** TERM ***
# Wielandsthal
# *** TERM ***
# Wielandseiten Alpe
# *** TERM ***
# Wetzles
# *** TERM ***
# Wetterkreuz
# *** TERM ***
# Werning
# *** TERM ***
# Wernhartalm
# *** TERM ***
# Werndorf
# *** TERM ***
# Wernberg
# *** TERM ***
# Wels
# *** TERM ***
# Weizelsdorf
# *** TERM ***
# Weitensfeld
# *** TERM ***
# Weissspitz
# *** TERM ***
# Weissseekopf
# *** TERM ***
# Weissleiten
# *** TERM ***
# Weisshaus
# *** TERM ***
# Weisses Kreuz
# *** TERM ***
# Weinzodl
# *** TERM ***
# Weinzettl
# *** TERM ***
# Weins
# *** TERM ***
# Weindorf
# *** TERM ***
# Weidinger
# *** TERM ***
# Weiding
# *** TERM ***
# Weichsee
# *** TERM ***
# Wechselkopf
# *** TERM ***
# Watzlberg
# *** TERM ***
# Wasserleith
# *** TERM ***
# Waschbach
# *** TERM ***
# Wannig
# *** TERM ***
# Wangham
# *** TERM ***
# Wangauer Ache
# *** TERM ***
# Waldsdorf
# *** TERM ***
# Waldreichs
# *** TERM ***
# Waldner
# *** TERM ***
# Waldenstein
# *** TERM ***
# Waldbach
# *** TERM ***
# Walcher Hochalm
# *** TERM ***
# Walchenbach
# *** TERM ***
# Waisacher Alm
# *** TERM ***
# Waidhoferalm
# *** TERM ***
# Politischer Bezirk Waidhofen an der Thaya
# *** TERM ***
# Waiden
# *** TERM ***
# Wagram
# *** TERM ***
# Wagrainerhohe
# *** TERM ***
# Waging
# *** TERM ***
# Waggendorf
# *** TERM ***
# Wagenitzsee
# *** TERM ***
# Wagenhub
# *** TERM ***
# Wackersbach
# *** TERM ***
# Wachtel
# *** TERM ***
# Waasen am Berg
# *** TERM ***
# Waasen
# *** TERM ***
# Prusmyk Vysebrodsky
# *** TERM ***
# Vormauerstein
# *** TERM ***
# Vorderverjunsalpe
# *** TERM ***
# Vordertambergau
# *** TERM ***
# Vorderkoflach
# *** TERM ***
# Vordere Strimshutte
# *** TERM ***
# Vorauer
# *** TERM ***
# Voisthalerhuette
# *** TERM ***
# Vois
# *** TERM ***
# Voecklamarkt
# *** TERM ***
# Villgrater Toerl
# *** TERM ***
# Villacher Alpe
# *** TERM ***
# Viechtwang
# *** TERM ***
# Vestennotting
# *** TERM ***
# Croda Vernaga
# *** TERM ***
# Vellacher Kotschna
# *** TERM ***
# Bad Vellach
# *** TERM ***
# Urtel Bach
# *** TERM ***
# Politischer Bezirk Urfahr-Umgebung
# *** TERM ***
# Unzmarkt
# *** TERM ***
# Unzing
# *** TERM ***
# Unterwolfsbach
# *** TERM ***
# Unterwalden
# *** TERM ***
# Untertreubach
# *** TERM ***
# Unterthal
# *** TERM ***
# Untertal
# *** TERM ***
# Unterstinkenbrunn
# *** TERM ***
# Untersiebenbrunn
# *** TERM ***
# Unterseeb
# *** TERM ***
# Unter Sankt Georgen
# *** TERM ***
# Unterrossegg
# *** TERM ***
# Unterrohrendorf
# *** TERM ***
# Unterrohrbach
# *** TERM ***
# Unterroedham
# *** TERM ***
# Unterriedl
# *** TERM ***
# Unterprenning
# *** TERM ***
# Radlem
# *** TERM ***
# Unter Ollinger
# *** TERM ***
# Untermuehlau
# *** TERM ***
# Untermoos
# *** TERM ***
# Untermicheldorf
# *** TERM ***
# Unterleidenberg
# *** TERM ***
# Unterleibnig
# *** TERM ***
# Unterlamm
# *** TERM ***
# Unterlabill
# *** TERM ***
# Unterkriech
# *** TERM ***
# Unterkirchen
# *** TERM ***
# Unterhaslberg
# *** TERM ***
# Unterhasel
# *** TERM ***
# Unterhall
# *** TERM ***
# Untergermating
# *** TERM ***
# Unterfeld
# *** TERM ***
# Unterfahrenbach
# *** TERM ***
# Untere Wildgruben Spitze
# *** TERM ***
# Unteres Lavanttal
# *** TERM ***
# Unterer Giglachsee
# *** TERM ***
# Unterer Eisenkopf
# *** TERM ***
# Ischkarneialpe
# *** TERM ***
# Untereglsee
# *** TERM ***
# Unteredt
# *** TERM ***
# Unterdoerfl
# *** TERM ***
# Unterdanegg
# *** TERM ***
# Unteraubach
# *** TERM ***
# Unterassling
# *** TERM ***
# Untschenspitze
# *** TERM ***
# Ulmer Huette
# *** TERM ***
# Ullrichsdorf
# *** TERM ***
# Schloss Uhlheim
# *** TERM ***
# UEbelstein
# *** TERM ***
# Tyrnauer Alpe
# *** TERM ***
# Tuxerjochhaus
# *** TERM ***
# Tuxbach
# *** TERM ***
# Tutzach
# *** TERM ***
# Turnauer Alpe
# *** TERM ***
# Turmberg
# *** TERM ***
# Turggeralm
# *** TERM ***
# Tuebinger Huette
# *** TERM ***
# Tschirtsch
# *** TERM ***
# Tscheuritsch
# *** TERM ***
# Tristkopf
# *** TERM ***
# Tristenspitze
# *** TERM ***
# Tristenkopf
# *** TERM ***
# Triplonalm
# *** TERM ***
# Trautmannsdorf an der Leitha
# *** TERM ***
# Traunwand Alpe
# *** TERM ***
# Trasischk
# *** TERM ***
# Traming
# *** TERM ***
# Tottendorf
# *** TERM ***
# Toescheldorf
# *** TERM ***
# Tonion
# *** TERM ***
# Tobadill
# *** TERM ***
# Tiefentalalm
# *** TERM ***
# Thures
# *** TERM ***
# Thumling
# *** TERM ***
# Thomasberg
# *** TERM ***
# Therner Berg
# *** TERM ***
# Thaur
# *** TERM ***
# Thanstetten
# *** TERM ***
# Thann
# *** TERM ***
# Thallein
# *** TERM ***
# Thalheim
# *** TERM ***
# Teufelhof
# *** TERM ***
# Terenbachalpe
# *** TERM ***
# Teipl Bach
# *** TERM ***
# Teichmanns
# *** TERM ***
# Taxachalm
# *** TERM ***
# Taurachbach
# *** TERM ***
# Tauglbach
# *** TERM ***
# Tasshof
# *** TERM ***
# Tatschenofen
# *** TERM ***
# Taschelbach
# *** TERM ***
# Tarrenz
# *** TERM ***
# Tanzelsdorf
# *** TERM ***
# Tangern
# *** TERM ***
# Tandel Alpe
# *** TERM ***
# Taiskirchen im Innkreis
# *** TERM ***
# Sutsch
# *** TERM ***
# Suessenbach
# *** TERM ***
# Susalitsch
# *** TERM ***
# Suppanalm
# *** TERM ***
# Sulzlbach
# *** TERM ***
# Sulzkar Alpe
# *** TERM ***
# Sulzenjoch
# *** TERM ***
# Sulzbach
# *** TERM ***
# Suedliche Talleiten Spitze
# *** TERM ***
# Stuetzenhofen
# *** TERM ***
# Stuttenhof
# *** TERM ***
# Stumpten
# *** TERM ***
# Stuhleck
# *** TERM ***
# Stubwieswipfel
# *** TERM ***
# Widhag
# *** TERM ***
# Stubachtal
# *** TERM ***
# Strudengau
# *** TERM ***
# Stroham
# *** TERM ***
# Strizl
# *** TERM ***
# Stritzling
# *** TERM ***
# Strelzhof
# *** TERM ***
# Streim Bach
# *** TERM ***
# Streiflehen
# *** TERM ***
# Stratberg
# *** TERM ***
# Stranzendorf
# *** TERM ***
# Straniger Alpe
# *** TERM ***
# Stranach
# *** TERM ***
# Straden
# *** TERM ***
# Stoettham
# *** TERM ***
# Stoelzles
# *** TERM ***
# Stollhof
# *** TERM ***
# Stojen
# *** TERM ***
# Stilluperhaus
# *** TERM ***
# Stillfried
# *** TERM ***
# Stillerbach
# *** TERM ***
# Stifterboden Huette
# *** TERM ***
# Stierriegel Bach
# *** TERM ***
# Stiegl
# *** TERM ***
# Stiefing
# *** TERM ***
# Stephanshart
# *** TERM ***
# Stellenkopf
# *** TERM ***
# Steinplan
# *** TERM ***
# Steinmandl
# *** TERM ***
# Steinerner Tisch
# *** TERM ***
# Steinerberg
# *** TERM ***
# Steinbrunn
# *** TERM ***
# Steinberg am Rofan
# *** TERM ***
# Steinaweg
# *** TERM ***
# Steinapiesting
# *** TERM ***
# Stein an der Donau
# *** TERM ***
# Starzeljoch
# *** TERM ***
# Stanzscharte
# *** TERM ***
# Staniska
# *** TERM ***
# Stang
# *** TERM ***
# Stampferalm
# *** TERM ***
# Staller Alm
# *** TERM ***
# Stainach
# *** TERM ***
# Stadt
# *** TERM ***
# Stadl Paura
# *** TERM ***
# Spitzstein
# *** TERM ***
# Spitznock
# *** TERM ***
# Spenger Kogel
# *** TERM ***
# Speising
# *** TERM ***
# Speikkogel
# *** TERM ***
# Speiereckhutte
# *** TERM ***
# Spateck
# *** TERM ***
# Sparbach
# *** TERM ***
# Sassberg
# *** TERM ***
# Sonntagskar Kogel
# *** TERM ***
# Sonntagsbuehel
# *** TERM ***
# Sonntagberg
# *** TERM ***
# Sonnspitze
# *** TERM ***
# Sonnleitberg
# *** TERM ***
# Sonnegg
# *** TERM ***
# Stubacher Sonnblick
# *** TERM ***
# Sommertor
# *** TERM ***
# Sollheim
# *** TERM ***
# Sophienalpe
# *** TERM ***
# Sittenberg
# *** TERM ***
# Sipbach
# *** TERM ***
# Sinzendorf
# *** TERM ***
# Sinnhuber
# *** TERM ***
# Singsdorf
# *** TERM ***
# Simmerlach
# *** TERM ***
# Sillwerk
# *** TERM ***
# Sillweg
# *** TERM ***
# Siglitz Bach
# *** TERM ***
# Sierningbach
# *** TERM ***
# Sierning
# *** TERM ***
# Sielach
# *** TERM ***
# Siegendorf im Burgenland
# *** TERM ***
# Siegelberg
# *** TERM ***
# Siebensee
# *** TERM ***
# Siebenlinden
# *** TERM ***
# Sexegertenferner
# *** TERM ***
# Senning
# *** TERM ***
# Semering
# *** TERM ***
# Selesen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-97cf032b754d> in <cell line: 10>()
#      18       f"""{source_information}"""
#      19   )
# ---> 20   predicted_type = predict_answer(term, combined_information)["Predicted Type: "]
#      21   # construct result
#      22   result_dict = {}
#
# <ipython-input-14-aacb2503f2b0> in predict_answer(term, combined_information, ref_type)
#      97     input_ids = torch.tensor(inputs["input_ids"], dtype=torch.long).to(DEVICE).unsqueeze(0)
#      98     attention_mask = torch.tensor(inputs["attention_mask"], dtype=torch.long).to(DEVICE).unsqueeze(0)
# ---> 99     outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask)
#     100     predicted_type = tokenizer.decode(outputs.flatten(), skip_special_tokens=True)
#     101
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1912
#    1913             # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1914             result = self._sample(
#    1915                 input_ids,
#    1916                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2649
#    2650             # forward pass to get next token
# -> 2651             outputs = self(
#    2652                 **model_inputs,
#    2653                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1737
#    1738         # Decode
# -> 1739         decoder_outputs = self.decoder(
#    1740             input_ids=decoder_input_ids,
#    1741             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1104                 )
#    1105             else:
# -> 1106                 layer_outputs = layer_module(
#    1107                     hidden_states,
#    1108                     attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     714                 query_length = None
#     715
# --> 716             cross_attention_outputs = self.layer[1](
#     717                 hidden_states,
#     718                 key_value_states=encoder_hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     624         output_attentions=False,
#     625     ):
# --> 626         normed_hidden_states = self.layer_norm(hidden_states)
#     627         attention_output = self.EncDecAttention(
#     628             normed_hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states)
#     243         # half-precision inputs is done in fp32
#     244
# --> 245         variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)
#     246         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     247
#
# KeyboardInterrupt:
